# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
import numpy as np
from sklearn.model_selection import train_test_split
from skimage.transform import resize
import os
import cv2
from PIL import Image as PILImage
import keras.backend as K
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import MeanIoU

# %%
# !pip install scikit-image --quiet

# %%
IMG_HEIGHT = 256
IMG_WIDTH = 256
IMG_CHANNEL = 3
BATCH_SIZE = 8
EPOCHS = 150
SEED = 13
smooth = 1.0

# %%
# Define directories for images and masks
image_directory = '/kaggle/input/betel-seg/Dataset for Segmentation/images'  # Update this path to your actual image directory
mask_directory = '/kaggle/input/betel-seg/Dataset for Segmentation/masks'  # Update this path to your actual mask directory

# %%
images = sorted(os.listdir(image_directory))
masks = sorted(os.listdir(mask_directory))

# %%
# Print image and corresponding mask names to check alignment
for i, image_name in enumerate(images[:5]):  # Checking first 5 examples
    mask_name = masks[i]
    print(f"Image: {image_name} -> Mask: {mask_name}")
# Out:
# Image: Bacterial_Leaf_Spot_Disease(1).jpg -> Mask: Bacterial_Leaf_Spot_Disease(1).png
# Image: Bacterial_Leaf_Spot_Disease(10).jpg -> Mask: Bacterial_Leaf_Spot_Disease(10).png
# Image: Bacterial_Leaf_Spot_Disease(100).jpg -> Mask: Bacterial_Leaf_Spot_Disease(100).png
# Image: Bacterial_Leaf_Spot_Disease(101).jpg -> Mask: Bacterial_Leaf_Spot_Disease(101).png
# Image: Bacterial_Leaf_Spot_Disease(102).jpg -> Mask: Bacterial_Leaf_Spot_Disease(102).png

# %%
image_basenames = [os.path.splitext(image)[0] for image in images]
mask_basenames = [os.path.splitext(mask)[0] for mask in masks]

# Check for missing masks
missing_masks = [image for image in image_basenames if image not in mask_basenames]

# Check for extra masks
extra_masks = [mask for mask in mask_basenames if mask not in image_basenames]

# Output results
print(f"Total images: {len(images)}")
print(f"Total masks: {len(masks)}")
print(f"Images missing masks: {len(missing_masks)}")
for missing in missing_masks:
    print(f"Missing mask for image: {missing}")

if extra_masks:
    print(f"\nExtra masks found ({len(extra_masks)}):")
    for extra in extra_masks:
        print(f"Extra mask without an image: {extra}")
# Out:
# Total images: 992
# Total masks: 971
# Images missing masks: 22
# Missing mask for image: Bacterial_Leaf_Spot_Disease(167)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(193)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(236)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(247)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(33)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(53)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(54)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(61)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(62)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(66)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(71)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(81)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(82)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(85)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(88)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(93)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(94)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(95)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(97)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(98)
# Missing mask for image: Healthy_Leaf(102)
# Missing mask for image: Healthy_Leaf(103)
#
# Extra masks found (1):
# Extra mask without an image: Fungal_Brown_Spot_Disease-64-_jpg.rf.5a379f0a955b73ce9372a460b2c2b5fb(1)

# %%
# Filter out images without matching masks
valid_images = [image for image in images if os.path.splitext(image)[0] in mask_basenames]

# Filter out masks without matching images (optional, if needed)
valid_masks = [mask for mask in masks if os.path.splitext(mask)[0] in image_basenames]

# Output results
print(f"Total valid images for training: {len(valid_images)}")
print(f"Total valid masks for training: {len(valid_masks)}")

# # For confirmation (optional)
# for image, mask in zip(valid_images, valid_masks):
#     print(f"Image: {image} | Mask: {mask}")
# Out:
# Total valid images for training: 970
# Total valid masks for training: 970

# %%
# from skimage.transform import resize
# import os
# import numpy as np
# from PIL import Image as PILImage
# import cv2
# from IPython.display import Image, display  # Import for displaying images in Jupyter

# # Define the size to which all images and masks will be resized
# IMG_HEIGHT = 256
# IMG_WIDTH = 256
# IMG_CHANNEL = 3  # For RGB images

# # Initialize lists to store the images and masks
# image_dataset = []
# mask_dataset = []

# # Ensure images and masks are sorted
# images = sorted(os.listdir(image_directory))
# masks = sorted(os.listdir(mask_directory))

# # Create a mapping of image filenames to mask filenames
# image_mask_map = {}
# for image_name in images:
#     if image_name.endswith('.jpg') or image_name.endswith('.png') or image_name.endswith('.tif'):
#         base_name = os.path.splitext(image_name)[0]
#         corresponding_mask = f"{base_name}.png"  # Assuming masks are in .png format
#         image_mask_map[image_name] = corresponding_mask

# # Load and process the images and masks
# for image_name, mask_name in image_mask_map.items():
#     if mask_name in masks:
#         # Read and process image
#         image_path = os.path.join(image_directory, image_name)
#         image = cv2.imread(image_path)
#         image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
#         image = resize(image, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)  # Resize using skimage
#         image = image.astype(np.uint8)  # Ensure the dtype is uint8
#         image_dataset.append(image)

#         # Display the image using IPython's Image
#         #display(PILImage.fromarray(image))  # For visualization in Jupyter

#         # Read and process mask
#         mask_path = os.path.join(mask_directory, mask_name)
#         mask = cv2.imread(mask_path, 0)  # Read in grayscale
#         mask = resize(mask, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)  # Resize using skimage
#         mask = np.expand_dims(mask, axis=-1)  # Add channel dimension (to get shape (H, W, 1))
#         mask = mask.astype(bool)  # Use built-in Python bool type
#         mask_dataset.append(mask)



# # Convert lists to NumPy arrays
# image_dataset = np.array(image_dataset)
# mask_dataset = np.array(mask_dataset)

# # Normalize the images to the range [0, 1]
# image_dataset = image_dataset / 255.0

# # Ensure images and masks match in length
# assert len(image_dataset) == len(mask_dataset), "Number of images and masks don't match!"

# # Print a few to check they are paired correctly
# for i in range(5):
#     print(f"Image {i}: {images[i]} -> Mask {i}: {list(image_mask_map.values())[i]}")

# print(f"Image dataset shape: {image_dataset.shape}")
# print(f"Mask dataset shape: {mask_dataset.shape}")

# %%
# np.save('/content/drive/MyDrive/Betal Leaf_Project/Fresh Start/Models/Checkpoints/image_dataset.npy', image_dataset)
# np.save('/content/drive/MyDrive/Betal Leaf_Project/Fresh Start/Models/Checkpoints/mask_dataset.npy', mask_dataset)

# To load them back
image_dataset = np.load('/kaggle/input/np-arrays/image_dataset.npy')
mask_dataset = np.load('/kaggle/input/np-arrays/mask_dataset.npy')

# %%
from matplotlib import pyplot as plt
# Visualize the first image and its corresponding binary mask
plt.figure(figsize=(5, 5))
plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(image_dataset[0])

plt.subplot(1, 2, 2)
plt.title('Binary Mask')
plt.imshow(mask_dataset[0], cmap='gray')

plt.show()

# %%
x_train, x_val, y_train, y_val = train_test_split(
    image_dataset, mask_dataset, test_size=0.45, random_state=SEED, shuffle=True
)
# Check shapes
print(f"Training images shape: {x_train.shape}")  # Should be (num_samples, 128, 128, 3)
print(f"Training masks shape: {y_train.shape}")   # Should be (num_samples, 128, 128, 1)
print(f"Validation images shape: {x_val.shape}")  # Should be (num_samples, 128, 128, 3)
print(f"Validation masks shape: {y_val.shape}")   # Should be (num_samples, 128, 128, 1)
# Out:
# Training images shape: (533, 256, 256, 3)
# Training masks shape: (533, 256, 256, 1)
# Validation images shape: (437, 256, 256, 3)
# Validation masks shape: (437, 256, 256, 1)

# %%
# Training data augmentation
data_gen_args = dict(rotation_range=90.,
                         width_shift_range=0.2,
                         height_shift_range=0.2,
                         shear_range=0.3,
                         zoom_range=0.3,
                         horizontal_flip=True,
                         vertical_flip=True,
                         fill_mode='reflect')

# Apply augmentation only for training data
X_datagen = ImageDataGenerator(**data_gen_args)
Y_datagen = ImageDataGenerator(**data_gen_args)

# No augmentation for validation data
X_datagen_val = ImageDataGenerator()  # Default, no augmentation
Y_datagen_val = ImageDataGenerator()  # Default, no augmentation

# Fitting generators for training data
X_datagen.fit(x_train, augment=True, seed=13)
Y_datagen.fit(y_train, augment=True, seed=13)

# Fitting generators for validation data (no augmentation)
X_datagen_val.fit(x_val, augment=False, seed=13)
Y_datagen_val.fit(y_val, augment=False, seed=13)

# Creating the data generators
X_train_augmented = X_datagen.flow(x_train, batch_size=8, shuffle=True, seed=13)
Y_train_augmented = Y_datagen.flow(y_train, batch_size=8, shuffle=True, seed=13)

# Validation data without augmentation
X_train_augmented_val = X_datagen_val.flow(x_val, batch_size=8, shuffle=False, seed=13)
Y_train_augmented_val = Y_datagen_val.flow(y_val, batch_size=8, shuffle=False, seed=13)

# Zip the augmented generators for training and validation
train_generator = zip(X_train_augmented, Y_train_augmented)
val_generator = zip(X_train_augmented_val, Y_train_augmented_val)

# %%
import matplotlib.pyplot as plt

def visualize_augmentation(generator, num_samples=5):
    plt.figure(figsize=(12, 8))
    for i in range(num_samples):
        batch = next(generator)
        images = batch[0]
        masks = batch[1]

        plt.subplot(num_samples, 2, 2*i + 1)
        plt.imshow(images[0])  # Display the first image of the batch
        plt.title('Augmented Image')
        plt.axis('off')

        plt.subplot(num_samples, 2, 2*i + 2)
        plt.imshow(masks[0].squeeze(), cmap='gray')  # Display the first mask of the batch
        plt.title('Augmented Mask')
        plt.axis('off')

    plt.show()

# Visualize augmented training images and masks
visualize_augmentation(train_generator, num_samples=5)

# %%
import tensorflow as tf
from tensorflow.keras.losses import CategoricalCrossentropy

# Dice loss function for multiclass segmentation
def dice_loss_multiclass(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    # One-hot encode y_pred if it's not already
    if y_pred.shape[-1] != y_true.shape[-1]:
        y_pred = tf.one_hot(tf.argmax(y_pred, axis=-1), depth=y_true.shape[-1])

    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    denominator = tf.reduce_sum(y_true + y_pred, axis=[1, 2, 3])
    dice = tf.reduce_mean((numerator + smooth) / (denominator + smooth), axis=0)
    return 1 - dice

# Combined loss: categorical cross-entropy + dice loss
def combined_multiclass_loss(y_true, y_pred):
    categorical_loss = CategoricalCrossentropy(from_logits=False)
    return categorical_loss(y_true, y_pred) + dice_loss_multiclass(y_true, y_pred)

# IOU metric for multiclass segmentation
def iou_multiclass(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)

    # Convert y_pred to one-hot encoding if necessary
    if y_pred.shape[-1] != y_true.shape[-1]:
        y_pred = tf.one_hot(tf.argmax(y_pred, axis=-1), depth=y_true.shape[-1])

    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true + y_pred, axis=[1, 2, 3]) - intersection
    iou = tf.reduce_mean((intersection + smooth) / (union + smooth), axis=0)
    return iou

# Dice coefficient metric for multiclass segmentation
def dice_coef_multiclass(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)

    # Convert y_pred to one-hot encoding if necessary
    if y_pred.shape[-1] != y_true.shape[-1]:
        y_pred = tf.one_hot(tf.argmax(y_pred, axis=-1), depth=y_true.shape[-1])

    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    denominator = tf.reduce_sum(y_true + y_pred, axis=[1, 2, 3])
    dice = tf.reduce_mean((numerator + smooth) / (denominator + smooth), axis=0)
    return dice

# %%
from keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, Dropout, MaxPooling2D, Conv2DTranspose, concatenate, BatchNormalization, Activation
from keras.regularizers import l2


SIZE=256

import tensorflow as tf
from tensorflow.keras import layers, models, regularizers

def residual_block(x, filters, kernel_size=3, stride=1, regularizer=None, dropout_rate=0.0, activation='relu'):
    # First convolution
    conv = layers.Conv2D(filters, kernel_size, strides=stride, padding='same',
                         kernel_regularizer=regularizer)(x)
    conv = layers.BatchNormalization()(conv)
    conv = layers.Activation(activation)(conv)
    
    # Second convolution
    conv = layers.Conv2D(filters, kernel_size, strides=1, padding='same',
                         kernel_regularizer=regularizer)(conv)
    conv = layers.BatchNormalization()(conv)

    # Skip connection
    shortcut = layers.Conv2D(filters, kernel_size=1, strides=stride, padding='same',
                             kernel_regularizer=regularizer)(x)
    shortcut = layers.BatchNormalization()(shortcut)

    # Combine and activate
    output = layers.Add()([conv, shortcut])
    output = layers.Activation(activation)(output)
    
    if dropout_rate > 0:
        output = layers.Dropout(dropout_rate)(output)

    return output

def StateOfArtResUNet(input_shape, num_classes, reg_value=1e-4, dropout_rate=0.1):
    inputs = layers.Input(shape=input_shape)

    # Encoder
    conv1 = residual_block(inputs, 64, regularizer=regularizers.l2(reg_value), dropout_rate=dropout_rate)
    pool1 = layers.MaxPooling2D((2, 2))(conv1)

    conv2 = residual_block(pool1, 128, regularizer=regularizers.l2(reg_value), dropout_rate=dropout_rate)
    pool2 = layers.MaxPooling2D((2, 2))(conv2)

    conv3 = residual_block(pool2, 256, regularizer=regularizers.l2(reg_value), dropout_rate=dropout_rate)
    pool3 = layers.MaxPooling2D((2, 2))(conv3)

    conv4 = residual_block(pool3, 512, regularizer=regularizers.l2(reg_value), dropout_rate=dropout_rate)
    pool4 = layers.MaxPooling2D((2, 2))(conv4)

    # Bridge
    bridge = residual_block(pool4, 1024, regularizer=regularizers.l2(reg_value), dropout_rate=dropout_rate)

    # Decoder
    upconv4 = layers.Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(bridge)
    concat4 = layers.Concatenate()([upconv4, conv4])
    conv5 = residual_block(concat4, 512, regularizer=regularizers.l2(reg_value), dropout_rate=dropout_rate)

    upconv3 = layers.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5)
    concat3 = layers.Concatenate()([upconv3, conv3])
    conv6 = residual_block(concat3, 256, regularizer=regularizers.l2(reg_value), dropout_rate=dropout_rate)

    upconv2 = layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6)
    concat2 = layers.Concatenate()([upconv2, conv2])
    conv7 = residual_block(concat2, 128, regularizer=regularizers.l2(reg_value), dropout_rate=dropout_rate)

    upconv1 = layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7)
    concat1 = layers.Concatenate()([upconv1, conv1])
    conv8 = residual_block(concat1, 64, regularizer=regularizers.l2(reg_value), dropout_rate=dropout_rate)

    # Output Layer
    activation = 'softmax' if num_classes > 1 else 'sigmoid'
    outputs = layers.Conv2D(num_classes, (1, 1), activation=activation)(conv8)

    model = models.Model(inputs, outputs)
    return model

# Instantiate the model
input_shape = (256, 256, 3)
num_classes = 4  # Example for multi-class segmentation
reg_value = 1e-4  # Reduced regularization to prevent underfitting
dropout_rate = 0.2  # Balanced dropout rate

model = StateOfArtResUNet(input_shape, num_classes, reg_value, dropout_rate)

# Print the summary of the model
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 256, 256, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 256, 256, 64)   │          1,792 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 256, 256, 64)   │            256 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation (Activation)   │ (None, 256, 256, 64)   │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 256, 256, 64)   │         36,928 │ activation[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 256, 256, 64)   │            256 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 256, 256, 64)   │            256 │ conv2d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 256, 256, 64)   │            256 │ conv2d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 256, 256, 64)   │              0 │ batch_normalization_1… │
# │                           │                        │                │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_1 (Activation) │ (None, 256, 256, 64)   │              0 │ add[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 256, 256, 64)   │              0 │ activation_1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 128, 128, 64)   │              0 │ dropout[0][0]          │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 128, 128,
│ concatenate_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_24    │ (None, 256, 256, 64)   │            256 │ conv2d_24[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_16             │ (None, 256, 256, 64)   │              0 │ batch_normalization_2… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_25 (Conv2D)        │ (None, 256, 256, 64)   │         36,928 │ activation_16[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_26 (Conv2D)        │ (None, 256, 256, 64)   │          8,256 │ concatenate_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_25    │ (None, 256, 256, 64)   │            256 │ conv2d_25[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_26    │ (None, 256, 256, 64)   │            256 │ conv2d_26[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_8 (Add)               │ (None, 256, 256, 64)   │              0 │ batch_normalization_2… │
# │                           │                        │                │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_17             │ (None, 256, 256, 64)   │              0 │ add_8[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_8 (Dropout)       │ (None, 256, 256, 64)   │              0 │ activation_17[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_27 (Conv2D)        │ (None, 256, 256, 4)    │            260 │ dropout_8[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 32,463,044 (123.84 MB)
#  Trainable params: 32,445,380 (123.77 MB)
#  Non-trainable params: 17,664 (69.00 KB)

# %%
def combined_generator(image_gen, mask_gen):
    while True:
        X = image_gen.__next__()
        Y = mask_gen.__next__()
        if X.shape[0] == Y.shape[0]:

            Y = tf.one_hot(tf.cast(Y, tf.int32), depth=4)
            Y = tf.squeeze(Y, axis=3)
            yield X, Y

# Create TensorFlow datasets
train_dataset = tf.data.Dataset.from_generator(
    lambda: combined_generator(X_train_augmented, Y_train_augmented),
    output_signature=(
        tf.TensorSpec(shape=(None, SIZE, SIZE, 3), dtype=tf.float32),
        tf.TensorSpec(shape=(None, SIZE, SIZE, 4), dtype=tf.float32)  # Changed to 4 channels
    )
)

val_dataset = tf.data.Dataset.from_generator(
    lambda: combined_generator(X_train_augmented_val, Y_train_augmented_val),
    output_signature=(
        tf.TensorSpec(shape=(None, SIZE, SIZE, 3), dtype=tf.float32),
        tf.TensorSpec(shape=(None, SIZE, SIZE, 4), dtype=tf.float32)  # Changed to 4 channels
    )
)

# Instanti

# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
              loss=combined_multiclass_loss,
              metrics=['accuracy', dice_coef_multiclass, iou_multiclass])

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', patience=15, verbose=1, factor=0.5, min_lr=1e-3)
checkpoint = ModelCheckpoint('/kaggle/working//unet_original.keras', monitor='val_loss', verbose=1, save_best_only=True)

# Train the model
EPOCHS = 100
BATCH_SIZE = 8
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=[early_stopping, checkpoint, reduce_lr],
    steps_per_epoch=len(x_train) // BATCH_SIZE,
    validation_steps=len(x_val) // BATCH_SIZE
)
# Out:
# Epoch 1/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4691 - dice_coef_multiclass: 0.4098 - iou_multiclass: 0.2707 - loss: 2.7035
# Epoch 1: val_loss improved from inf to 2.32787, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 198s 2s/step - accuracy: 0.4708 - dice_coef_multiclass: 0.4111 - iou_multiclass: 0.2718 - loss: 2.6976 - val_accuracy: 0.6507 - val_dice_coef_multiclass: 0.4422 - val_iou_multiclass: 0.2984 - val_loss: 2.3279 - learning_rate: 1.0000e-04
# Epoch 2/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 637ms/step - accuracy: 0.6950 - dice_coef_multiclass: 0.6104 - iou_multiclass: 0.4615 - loss: 1.7917
# Epoch 2: val_loss improved from 2.32787 to 2.06549, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 57s 866ms/step - accuracy: 0.6951 - dice_coef_multiclass: 0.6107 - iou_multiclass: 0.4618 - loss: 1.7907 - val_accuracy: 0.6484 - val_dice_coef_multiclass: 0.5356 - val_iou_multiclass: 0.4026 - val_loss: 2.0655 - learning_rate: 1.0000e-04
# Epoch 3/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 605ms/step - accuracy: 0.7526 - dice_coef_multiclass: 0.6793 - iou_multiclass: 0.5436 - loss: 1.5169
# Epoch 3: val_loss improved from 2.06549 to 1.81441, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 53s 806ms/step - accuracy: 0.7522 - dice_coef_multiclass: 0.6790 - iou_multiclass: 0.5433 - loss: 1.5179 - val_accuracy: 0.6445 - val_dice_coef_multiclass: 0.5803 - val_iou_multiclass: 0.4356 - val_loss: 1.8144 - learning_rate: 1.0000e-04
# Epoch 4/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 605ms/step - accuracy: 0.7552 - dice_coef_multiclass: 0.6820 - iou_multiclass: 0.5466 - loss: 1.4667
# Epoch 4: val_loss improved from 1.81441 to 1.67971, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 53s 798ms/step - accuracy: 0.7551 - dice_coef_multiclass: 0.6820 - iou_multiclass: 0.5466 - loss: 1.4668 - val_accuracy: 0.6727 - val_dice_coef_multiclass: 0.6036 - val_iou_multiclass: 0.4525 - val_loss: 1.6797 - learning_rate: 1.0000e-04
# Epoch 5/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 613ms/step - accuracy: 0.7546 - dice_coef_multiclass: 0.6914 - iou_multiclass: 0.5594 - loss: 1.4146
# Epoch 5: val_loss did not improve from 1.67971
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 51s 773ms/step - accuracy: 0.7545 - dice_coef_multiclass: 0.6914 - iou_multiclass: 0.5594 - loss: 1.4146 - val_accuracy: 0.6485 - val_dice_coef_multiclass: 0.6195 - val_iou_multiclass: 0.4914 - val_loss: 1.7433 - learning_rate: 1.0000e-04
# Epoch 6/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 608ms/step - accuracy: 0.7319 - dice_coef_multiclass: 0.6785 - iou_multiclass: 0.5476 - loss: 1.3999
# Epoch 6: val_loss improved from 1.67971 to 1.64160, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 53s 804ms/step - accuracy: 0.7321 - dice_coef_multiclass: 0.6786 - iou_multiclass: 0.5477 - loss: 1.3994 - val_accuracy: 0.6810 - val_dice_coef_multiclass: 0.6038 - val_iou_multiclass: 0.4584 - val_loss: 1.6416 - learning_rate: 1.0000e-04
# Epoch 7/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 618ms/step - accuracy: 0.7494 - dice_coef_multiclass: 0.6882 - iou_multiclass: 0.5618 - loss: 1.3619
# Epoch 7: val_loss did not improve from 1.64160
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 51s 778ms/step - accuracy: 0.7496 - dice_coef_multiclass: 0.6885 - iou_multiclass: 0.5621 - loss: 1.3612 - val_accuracy: 0.7065 - val_dice_coef_multiclass: 0.6008 - val_iou_multiclass: 0.4427 - val_loss: 1.6686 - learning_rate: 1.0000e-04
# Epoch 8/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 604ms/step - accuracy: 0.7550 - dice_coef_multiclass: 0.6915 - iou_multiclass: 0.5627 - loss: 1.3516
# Epoch 8: val_loss improved from 1.64160 to 1.41291, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 53s 801ms/step - accuracy: 0.7551 - dice_coef_multiclass: 0.6916 - iou_multiclass: 0.5628 - loss: 1.3509 - val_accuracy: 0.7198 - val_dice_coef_multiclass: 0.6218 - val_iou_multiclass: 0.4636 - val_loss: 1.4129 - learning_rate: 1.0000e-04
# Epoch 9/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 613ms/step - accuracy: 0.8100 - dice_coef_multiclass: 0.7475 - iou_multiclass: 0.6305 - loss: 1.1651
# Epoch 9: val_loss did not improve from 1.41291
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 51s 773ms/step - accuracy: 0.8097 - dice_coef_multiclass: 0.7472 - iou_multiclass: 0.6303 - loss: 1.1659 - val_accuracy: 0.6628 - val_dice_coef_multiclass: 0.6080 - val_iou_multiclass: 0.4605 - val_loss: 1.5880 - learning_rate: 1.0000e-04
# Epoch 10/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 605ms/step - accuracy: 0.7840 - dice_coef_multiclass: 0.7286 - iou_multiclass: 0.6084 - loss: 1.2026
# Epoch 10: val_loss did not improve from 1.41291
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 50s 765ms/step - accuracy: 0.7840 - dice_coef_multiclass: 0.7286 - iou_multiclass: 0.6084 - loss: 1.2026 - val_accuracy: 0.6823 - val_dice_coef_multiclass: 0.6327 - val_iou_multiclass: 0.5082 - val_loss: 1.5363 - learning_rate: 1.0000e-04
# Epoch 11/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 607ms/step - accuracy: 0.7780 - dice_coef_multiclass: 0.7199 - iou_multiclass: 0.5956 - loss: 1.2060
# Epoch 11: val_loss improved from 1.41291 to 1.17837, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 53s 804ms/step - accuracy: 0.7782 - dice_coef_multiclass: 0.7201 - iou_multiclass: 0.5958 - loss: 1.2057 - val_accuracy: 0.7795 - val_dice_coef_multiclass: 0.7213 - val_iou_multiclass: 0.5996 - val_loss: 1.1784 - learning_rate: 1.0000e-04
# Epoch 12/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 612ms/step - accuracy: 0.8046 - dice_coef_multiclass: 0.7467 - iou_multiclass: 0.6317 - loss: 1.1195
# Epoch 12: val_loss improved from 1.17837 to 1.14903, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 53s 810ms/step - accuracy: 0.8047 - dice_coef_multiclass: 0.7468 - iou_multiclass: 0.6318 - loss: 1.1194 - val_accuracy: 0.7856 - val_dice_coef_multiclass: 0.7249 - val_iou_multiclass: 0.5992 - val_loss: 1.1490 - learning_rate: 1.0000e-04
# Epoch 13/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 609ms/step - accuracy: 0.8048 - dice_coef_multiclass: 0.7523 - iou_multiclass: 0.6371 - loss: 1.1115
# Epoch 13: val_loss did not improve from 1.14903
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 51s 771ms/step - accuracy: 0.8049 - dice_coef_multiclass: 0.7524 - iou_multiclass: 0.6372 - loss: 1.1112 - val_accuracy: 0.6633 - val_dice_coef_multiclass: 0.6476 - val_iou_multiclass: 0.5401 - val_loss: 1.4292 - learning_rate: 1.0000e-04
# Epoch 14/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 611ms/step - accuracy: 0.8047 - dice_coef_multiclass: 0.7519 - iou_multiclass: 0.6391 - loss: 1.1221
# Epoch 14: val_loss improved from 1.14903 to 1.02702, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 53s 808ms/step - accuracy: 0.8046 - dice_coef_multiclass: 0.7518 - iou_multiclass: 0.6390 - loss: 1.1221 - val_accuracy: 0.8127 - val_dice_coef_multiclass: 0.7485 - val_iou_multiclass: 0.6296 - val_loss: 1.0270 - learning_rate: 1.0000e-04
# Epoch 15/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 612ms/step - accuracy: 0.8203 - dice_coef_multiclass: 0.7666 - iou_multiclass: 0.6574 - loss: 1.0368
# Epoch 15: val_loss did not improve from 1.02702
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 51s 773ms/step - accuracy: 0.8202 - dice_coef_multiclass: 0.7665 - iou_multiclass: 0.6573 - loss: 1.0371 - val_accuracy: 0.7455 - val_dice_coef_multiclass: 0.6814 - val_iou_multiclass: 0.5537 - val_loss: 1.2094 - learning_rate: 1.0000e-04
# Epoch 16/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 607ms/step - accuracy: 0.7975 - dice_coef_multiclass: 0.7451 - iou_multiclass: 0.6336 - loss: 1.1041
# Epoch 16: val_loss did not improve from 1.02702
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 50s 767ms/step - accuracy: 0.7976 - dice_coef_multiclass: 0.7452 - iou_multiclass: 0.6336 - loss: 1.1039 - val_accuracy: 0.7398 - val_dice_coef_multiclass: 0.6797 - val_iou_multiclass: 0.5463 - val_loss: 1.1920 - learning_rate: 1.0000e-04
# Epoch 17/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 606ms/step - accuracy: 0.8259 - dice_coef_multiclass: 0.7664 - iou_multiclass: 0.6558 - loss: 1.0197
# Epoch 17: val_loss did not improve from 1.02702
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 50s 767ms/step - accuracy: 0.8258 - dice_coef_multiclass: 0.7663 - iou_multiclass: 0.6557 - loss: 1.0200 - val_accuracy: 0.7727 - val_dice_coef_multiclass: 0.7128 - val_iou_multiclass: 0.5907 - val_loss: 1.1181 - learning_rate: 1.0000e-04
# Epoch 18/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 611ms/step - accuracy: 0.8417 - dice_coef_multiclass: 0.7911 - iou_multiclass: 0.6864 - loss: 0.9644
# Epoch 18: val_loss improved from 1.02702 to 0.98197, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 53s
# Epoch 77/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 605ms/step - accuracy: 0.9084 - dice_coef_multiclass: 0.8778 - iou_multiclass: 0.8075 - loss: 0.5802
# Epoch 77: val_loss improved from 0.61206 to 0.60099, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 53s 804ms/step - accuracy: 0.9082 - dice_coef_multiclass: 0.8777 - iou_multiclass: 0.8073 - loss: 0.5806 - val_accuracy: 0.9051 - val_dice_coef_multiclass: 0.8550 - val_iou_multiclass: 0.7648 - val_loss: 0.6010 - learning_rate: 1.0000e-04
# Epoch 78/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 614ms/step - accuracy: 0.9126 - dice_coef_multiclass: 0.8765 - iou_multiclass: 0.8034 - loss: 0.5677
# Epoch 78: val_loss did not improve from 0.60099
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 51s 776ms/step - accuracy: 0.9126 - dice_coef_multiclass: 0.8765 - iou_multiclass: 0.8034 - loss: 0.5677 - val_accuracy: 0.8537 - val_dice_coef_multiclass: 0.8004 - val_iou_multiclass: 0.7018 - val_loss: 0.7747 - learning_rate: 1.0000e-04
# Epoch 79/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 611ms/step - accuracy: 0.8954 - dice_coef_multiclass: 0.8640 - iou_multiclass: 0.7897 - loss: 0.6320
# Epoch 79: val_loss did not improve from 0.60099
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 51s 772ms/step - accuracy: 0.8955 - dice_coef_multiclass: 0.8641 - iou_multiclass: 0.7897 - loss: 0.6316 - val_accuracy: 0.8843 - val_dice_coef_multiclass: 0.8337 - val_iou_multiclass: 0.7365 - val_loss: 0.6597 - learning_rate: 1.0000e-04
# Epoch 80/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 607ms/step - accuracy: 0.9020 - dice_coef_multiclass: 0.8714 - iou_multiclass: 0.7981 - loss: 0.6050
# Epoch 80: val_loss improved from 0.60099 to 0.58382, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 53s 804ms/step - accuracy: 0.9020 - dice_coef_multiclass: 0.8714 - iou_multiclass: 0.7982 - loss: 0.6049 - val_accuracy: 0.9073 - val_dice_coef_multiclass: 0.8630 - val_iou_multiclass: 0.7769 - val_loss: 0.5838 - learning_rate: 1.0000e-04
# Epoch 81/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 614ms/step - accuracy: 0.8915 - dice_coef_multiclass: 0.8595 - iou_multiclass: 0.7801 - loss: 0.6381
# Epoch 81: val_loss did not improve from 0.58382
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 51s 776ms/step - accuracy: 0.8916 - dice_coef_multiclass: 0.8595 - iou_multiclass: 0.7803 - loss: 0.6377 - val_accuracy: 0.8630 - val_dice_coef_multiclass: 0.8371 - val_iou_multiclass: 0.7598 - val_loss: 0.7044 - learning_rate: 1.0000e-04
# Epoch 82/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 606ms/step - accuracy: 0.9016 - dice_coef_multiclass: 0.8759 - iou_multiclass: 0.8068 - loss: 0.5987
# Epoch 82: val_loss did not improve from 0.58382
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 50s 767ms/step - accuracy: 0.9017 - dice_coef_multiclass: 0.8759 - iou_multiclass: 0.8068 - loss: 0.5986 - val_accuracy: 0.9122 - val_dice_coef_multiclass: 0.8500 - val_iou_multiclass: 0.7562 - val_loss: 0.5912 - learning_rate: 1.0000e-04
# Epoch 83/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 612ms/step - accuracy: 0.9006 - dice_coef_multiclass: 0.8676 - iou_multiclass: 0.7916 - loss: 0.5972
# Epoch 83: val_loss did not improve from 0.58382
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 51s 776ms/step - accuracy: 0.9007 - dice_coef_multiclass: 0.8677 - iou_multiclass: 0.7917 - loss: 0.5970 - val_accuracy: 0.9028 - val_dice_coef_multiclass: 0.8303 - val_iou_multiclass: 0.7300 - val_loss: 0.6369 - learning_rate: 1.0000e-04
# Epoch 84/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 610ms/step - accuracy: 0.9002 - dice_coef_multiclass: 0.8638 - iou_multiclass: 0.7824 - loss: 0.6082
# Epoch 84: val_loss did not improve from 0.58382
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 51s 771ms/step - accuracy: 0.9003 - dice_coef_multiclass: 0.8639 - iou_multiclass: 0.7826 - loss: 0.6078 - val_accuracy: 0.8832 - val_dice_coef_multiclass: 0.8243 - val_iou_multiclass: 0.7258 - val_loss: 0.6670 - learning_rate: 1.0000e-04
# Epoch 85/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 604ms/step - accuracy: 0.9124 - dice_coef_multiclass: 0.8901 - iou_multiclass: 0.8249 - loss: 0.5497
# Epoch 85: val_loss did not improve from 0.58382
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 50s 765ms/step - accuracy: 0.9125 - dice_coef_multiclass: 0.8901 - iou_multiclass: 0.8249 - loss: 0.5497 - val_accuracy: 0.8632 - val_dice_coef_multiclass: 0.8168 - val_iou_multiclass: 0.7174 - val_loss: 0.7165 - learning_rate: 1.0000e-04
# Epoch 86/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 606ms/step - accuracy: 0.9121 - dice_coef_multiclass: 0.8850 - iou_multiclass: 0.8173 - loss: 0.5709
# Epoch 86: val_loss did not improve from 0.58382
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 50s 767ms/step - accuracy: 0.9121 - dice_coef_multiclass: 0.8851 - iou_multiclass: 0.8173 - loss: 0.5707 - val_accuracy: 0.8947 - val_dice_coef_multiclass: 0.8365 - val_iou_multiclass: 0.7449 - val_loss: 0.6337 - learning_rate: 1.0000e-04
# Epoch 87/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 611ms/step - accuracy: 0.9041 - dice_coef_multiclass: 0.8723 - iou_multiclass: 0.7991 - loss: 0.5889
# Epoch 87: val_loss improved from 0.58382 to 0.57459, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 53s 811ms/step - accuracy: 0.9041 - dice_coef_multiclass: 0.8723 - iou_multiclass: 0.7991 - loss: 0.5888 - val_accuracy: 0.9095 - val_dice_coef_multiclass: 0.8668 - val_iou_multiclass: 0.7858 - val_loss: 0.5746 - learning_rate: 1.0000e-04
# Epoch 88/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 613ms/step - accuracy: 0.9219 - dice_coef_multiclass: 0.8913 - iou_multiclass: 0.8228 - loss: 0.5229
# Epoch 88: val_loss did not improve from 0.57459
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 51s 775ms/step - accuracy: 0.9218 - dice_coef_multiclass: 0.8913 - iou_multiclass: 0.8227 - loss: 0.5231 - val_accuracy: 0.8951 - val_dice_coef_multiclass: 0.8431 - val_iou_multiclass: 0.7537 - val_loss: 0.6088 - learning_rate: 1.0000e-04
# Epoch 89/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 611ms/step - accuracy: 0.9072 - dice_coef_multiclass: 0.8809 - iou_multiclass: 0.8100 - loss: 0.5603
# Epoch 89: val_loss did not improve from 0.57459
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 51s 772ms/step - accuracy: 0.9072 - dice_coef_multiclass: 0.8809 - iou_multiclass: 0.8101 - loss: 0.5601 - val_accuracy: 0.8994 - val_dice_coef_multiclass: 0.8583 - val_iou_multiclass: 0.7753 - val_loss: 0.6012 - learning_rate: 1.0000e-04
# Epoch 90/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 605ms/step - accuracy: 0.8957 - dice_coef_multiclass: 0.8669 - iou_multiclass: 0.7964 - loss: 0.6069
# Epoch 90: val_loss improved from 0.57459 to 0.57203, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 53s 803ms/step - accuracy: 0.8957 - dice_coef_multiclass: 0.8669 - iou_multiclass: 0.7963 - loss: 0.6068 - val_accuracy: 0.9088 - val_dice_coef_multiclass: 0.8602 - val_iou_multiclass: 0.7728 - val_loss: 0.5720 - learning_rate: 1.0000e-04
# Epoch 91/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 613ms/step - accuracy: 0.9075 - dice_coef_multiclass: 0.8831 - iou_multiclass: 0.8154 - loss: 0.5445
# Epoch 91: val_loss did not improve from 0.57203
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 51s 775ms/step - accuracy: 0.9076 - dice_coef_multiclass: 0.8832 - iou_multiclass: 0.8155 - loss: 0.5444 - val_accuracy: 0.8727 - val_dice_coef_multiclass: 0.8374 - val_iou_multiclass: 0.7560 - val_loss: 0.6816 - learning_rate: 1.0000e-04
# Epoch 92/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 610ms/step - accuracy: 0.8994 - dice_coef_multiclass: 0.8705 - iou_multiclass: 0.7949 - loss: 0.5877
# Epoch 92: val_loss did not improve from 0.57203
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 51s 771ms/step - accuracy: 0.8996 - dice_coef_multiclass: 0.8706 - iou_multiclass: 0.7951 - loss: 0.5873 - val_accuracy: 0.9044 - val_dice_coef_multiclass: 0.8324 - val_iou_multiclass: 0.7323 - val_loss: 0.6253 - learning_rate: 1.0000e-04
# Epoch 93/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 607ms/step - accuracy: 0.9322 - dice_coef_multiclass: 0.9077 - iou_multiclass: 0.8477 - loss: 0.4862
# Epoch 93: val_loss did not improve from 0.57203
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 51s 768ms/step - accuracy: 0.9321 - dice_coef_multiclass: 0.9076 - iou_multiclass: 0.8475 - loss: 0.4867 - val_accuracy: 0.9058 - val_dice_coef_multiclass: 0.8512 - val_iou_multiclass: 0.7605 - val_loss: 0.6013 - learning_rate: 1.0000e-04
# Epoch 94/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 609ms/step - accuracy: 0.9084 - dice_coef_multiclass: 0.8791 - iou_multiclass: 0.8084 - loss: 0.5621
# Epoch 94: val_loss did not improve from 0.57203
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 51s 771ms/step - accuracy: 0.9084 - dice_coef_multiclass: 0.8791 - iou_multiclass: 0.8084 - loss: 0.5622 - val_accuracy: 0.8950 - val_dice_coef_multiclass: 0.8479 - val_iou_multiclass: 0.7607 - val_loss: 0.6158 - learning_rate: 1.0000e-04
# Epoch 95/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 613ms/step - accuracy: 0.8977 - dice_coef_multiclass: 0.8694 - iou_multiclass: 0.7975 - loss: 0.5870
# Epoch 95: val_loss did not improve from 0.57203
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 51s 776ms/step - accuracy: 0.8977 - dice_coef_multiclass: 0.8694 - iou_multiclass: 0.7976 - loss: 0.5870 - val_accuracy: 0.8644 - val_dice_coef_multiclass: 0.8344 - val_iou_multiclass: 0.7536 - val_loss: 0.7268 - learning_rate: 1.0000e-04
# Epoch 96/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 611ms/step - accuracy: 0.9085 - dice_coef_multiclass: 0.8835 - iou_multiclass: 0.8155 - loss: 0.5756
# Epoch 96: val_loss improved from 0.57203 to 0.54391, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 53s 809ms/step - accuracy: 0.9084 - dice_coef_multiclass: 0.8834 - iou_multiclass: 0.8153 - loss: 0.5757 - val_accuracy: 0.9186 - val_dice_coef_multiclass: 0.8730 - val_iou_multiclass: 0.7930 - val_loss: 0.5439 - learning_rate: 1.0000e-04
# Epoch 97/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 613ms/step - accuracy: 0.9221 - dice_coef_multiclass: 0.8950 - iou_multiclass: 0.8313 - loss: 0.5196
# Epoch 97: val_loss did not improve from 0.54391
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 51s 775ms/step - accuracy: 0.9220 - dice_coef_multiclass: 0.8949 - iou_multiclass: 0.8312 - loss: 0.5198 - val_accuracy: 0.8909 - val_dice_coef_multiclass: 0.8545 - val_iou_multiclass: 0.7723 - val_loss: 0.6254 - learning_rate: 1.0000e-04
# Epoch 98/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 606ms/step - accuracy: 0.9065 - dice_coef_multiclass: 0.8794 - iou_multiclass: 0.8094 - loss: 0.5661
# Epoch 98: val_loss did not improve from 0.54391
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 50s 766ms/step - accuracy: 0.9064 - dice_coef_multiclass: 0.8793 - iou_multiclass: 0.8092 - loss: 0.5663 - val_accuracy: 0.8964 - val_dice_coef_multiclass: 0.8467 - val_iou_multiclass: 0.7602 - val_loss: 0.6151 - learning_rate: 1.0000e-04
# Epoch 99/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 609ms/step - accuracy: 0.9184 - dice_coef_multiclass: 0.8870 - iou_multiclass: 0.8195 - loss: 0.5270
# Epoch 99: val_loss did not improve from 0.54391
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 51s 771ms/step - accuracy: 0.9185 - dice_coef_multiclass: 0.8871 - iou_multiclass: 0.8196 - loss: 0.5269 - val_accuracy: 0.8797 - val_dice_coef_multiclass: 0.8197 - val_iou_multiclass: 0.7222 - val_loss: 0.6722 - learning_rate: 1.0000e-04
# Epoch 100/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 613ms/step - accuracy: 0.9121 - dice_coef_multiclass: 0.8870 - iou_multiclass: 0.8212 - loss: 0.5496
# Epoch 100: val_loss did not improve from 0.54391
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 51s 776ms/step - accuracy: 0.9123 - dice_coef_multiclass: 0.8871 - iou_multiclass: 0.8214 - loss: 0.5491 - val_accuracy: 0.8784 - val_dice_coef_multiclass: 0.8424 - val_iou_multiclass: 0.7592 - val_loss: 0.6506 - learning_rate: 1.0000e-04

# %%
# Print the final training/validation loss and accuracy values
print("Final Training Loss: ", history.history['loss'][-1])
print("Final Validation Loss: ", history.history['val_loss'][-1])
print("Final Training Accuracy: ", history.history['accuracy'][-1])
print("Final Validation Accuracy: ", history.history['val_accuracy'][-1])
print("Final Training Dice Coefficient: ", history.history['dice_coef_multiclass'][-1])
print("Final Validation Dice Coefficient: ", history.history['val_dice_coef_multiclass'][-1])
print("Final Training IoU: ", history.history['iou_multiclass'][-1])
print("Final Validation IoU: ", history.history['val_iou_multiclass'][-1])
# Out:
# Final Training Loss:  0.5193791389465332
# Final Validation Loss:  0.650641143321991
# Final Training Accuracy:  0.9203767776489258
# Final Validation Accuracy:  0.8784253001213074
# Final Training Dice Coefficient:  0.8950843811035156
# Final Validation Dice Coefficient:  0.8423857092857361
# Final Training IoU:  0.8321553468704224
# Final Validation IoU:  0.7592117786407471

# %%
import matplotlib.pyplot as plt

# Plot training & validation loss, dice coefficient, and IoU over epochs
def plot_training_history(history):
    # Summarize history for loss, dice coefficient, and IoU
    plt.figure(figsize=(18, 6))  # Increase figure size for 3 plots

    # Plot loss
    plt.subplot(1, 3, 1)  # 1 row, 3 columns, first plot
    plt.plot(history.history['loss'], label='train_loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(loc='upper right')

    # Plot Dice Coefficient
    plt.subplot(1, 3, 2)  # 1 row, 3 columns, second plot
    plt.plot(history.history['dice_coef_multiclass'], label='train_dice_coef')
    plt.plot(history.history['val_dice_coef_multiclass'], label='val_dice_coef')
    plt.title('Model Dice Coefficient')
    plt.ylabel('Dice Coefficient')
    plt.xlabel('Epoch')
    plt.legend(loc='upper right')

    # Plot IoU
    plt.subplot(1, 3, 3)  # 1 row, 3 columns, third plot
    plt.plot(history.history['iou_multiclass'], label='train_iou_metric')
    plt.plot(history.history['val_iou_multiclass'], label='val_iou_metric')
    plt.title('Model IoU')
    plt.ylabel('IoU')
    plt.xlabel('Epoch')
    plt.legend(loc='upper right')

    plt.tight_layout()  # Adjust layout for better spacing
    plt.show()

# Call the function to plot
plot_training_history(history)

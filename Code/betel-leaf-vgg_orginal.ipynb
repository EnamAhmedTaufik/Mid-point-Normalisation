# %%
import tensorflow as tf
tf.keras.backend.clear_session()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import cv2
import os
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Model, Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.layers import Input, Conv2D

# %%
import numpy as np
import pandas as pd
import os

# %%
# # !pip install tensorflow numpy pandas matplotlib seaborn opencv-python tqdm scikit-learn --quiet
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import cv2
import os
import cv2
import numpy as np
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
# from tensorflow.keras.applications import preprocess_input
from tensorflow.keras import layers, models, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from tensorflow.keras.regularizers import l2

# %%
import tensorflow as tf

# Check if GPU is available
if tf.config.list_physical_devices('GPU'):
    print("Using GPU")
else:
    print("Using CPU")

print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Using GPU
# Num GPUs Available:  2

# %%
disease_types = ['Bacterial Leaf Disease','Fungal Brown Spot Disease','Dried Leaf','Healthy Leaf']
# disease_types = ['Bacterial Leaf Disease','Fungal Brown Spot Disease']

# data_dir = '/content/drive/MyDrive/Betal Leaf_Project/temp_Images'
data_dir = '/kaggle/input/betel-dataset/Resized 224_250'
train_dir = os.path.join(data_dir)
# test_dir = os.path.join(data_dir, 'test')

# %%
train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])

train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])
train.head(3)
# Out:
#                                                 File  DiseaseID  \
# 0  Bacterial Leaf Disease/Bacterial_Leaf_Spot_Dis...          0
# 1  Bacterial Leaf Disease/Bacterial_Leaf_Spot_Dis...          0
# 2  Bacterial Leaf Disease/Bacterial_Leaf_Spot_Dis...          0
#
#              Disease Type
# 0  Bacterial Leaf Disease
# 1  Bacterial Leaf Disease
# 2  Bacterial Leaf Disease

# %%
len(train_data)
# Out:
# 1000

# %%
# Randomize the order of training set
SEED = 42
train = train.sample(frac=1, random_state=SEED)
train.index = np.arange(len(train)) # Reset indices
train.head()
# Out:
#                                                 File  DiseaseID  \
# 0                      Dried Leaf/Dried_Leaf(94).jpg          2
# 1                     Dried Leaf/Dried_Leaf(151).jpg          2
# 2                       Dried Leaf/Dried_Leaf(2).jpg          2
# 3                     Dried Leaf/Dried_Leaf(149).jpg          2
# 4  Fungal Brown Spot Disease/Fungal_Brown_Spot_Di...          1
#
#                 Disease Type
# 0                 Dried Leaf
# 1                 Dried Leaf
# 2                 Dried Leaf
# 3                 Dried Leaf
# 4  Fungal Brown Spot Disease

# %%
IMAGE_SIZE = 224
SEED = 42

# def read_image(filepath):
    
#     # Step 1: Load the image
#     image = cv2.imread(os.path.join(data_dir, filepath))
#     image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

#     # Step 2: Resize the image
#     image_resized = cv2.resize(image, (IMAGE_SIZE, IMAGE_SIZE))

#     # Step 3: Normalize the image to the range [-1, 1]
#     image_normalized = (image_resized / 127.5) - 1.0

#     return image_normalized

#     return focused_image


def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath))

# %%
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))

for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = image
# Out:
# 1000it [00:03, 312.86it/s]

# %%
X_train = X_train / 255.0
print('Train Shape: {}'.format(X_train.shape))
Y_train = train['DiseaseID'].values
Y_train = to_categorical(Y_train, num_classes=4)
# Out:
# Train Shape: (1000, 224, 224, 3)

# %%
# Split the train and validation sets
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.3, random_state=SEED)

# %%
len(X_train)
# Out:
# 700

# %%
EPOCHS = 50
SIZE=224
N_ch=3

# %% [markdown]
# # Densenet

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.applications import VGG16
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

def build_vgg16():
    # Load the DenseNet201 model without the top layer
    # vgg16 = VGG16(input_shape=[224, 224, 3], weights='imagenet', include_top=False)


    vgg16 = VGG16(weights='imagenet', include_top=False, input_shape=(SIZE, SIZE, N_ch))

    # Input layer
    input_layer = Input(shape=(SIZE, SIZE, N_ch))

    # Initial Conv layer to adjust for input channels
    x = Conv2D(3, (5, 5), padding='same', activation='relu')(input_layer)

    # Freeze the layers of the pre-trained model
    for layer in vgg16.layers:
        layer.trainable = False
    x = vgg16(x)
    x = Conv2D(128, (5, 5), padding='same', activation='relu', name='last_conv')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # Dense layers for classification
    x = Dense(1024, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(512, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # Output layer for 4 classes
    output = Dense(4, kernel_regularizer=l2(0.01), activation='softmax', name='root')(x)

    # Create the model
    model = Model(input_layer, output)

    # Compile the model
    optimizer = Adam(learning_rate=1e-4)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

    return model

# Build the model
model = build_vgg16()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# def se_block(input_tensor, reduction_ratio=16):
#     filters = input_tensor.shape[-1]
#     se = layers.GlobalAveragePooling2D()(input_tensor)
#     se = layers.Reshape((1, 1, filters))(se)
#     se = layers.Dense(filters // reduction_ratio, activation='relu')(se)
#     se = layers.Dense(filters, activation='sigmoid')(se)
#     se = layers.Multiply()([input_tensor, se])
#     return se

# # Custom CNN with Attention
# def build_attention_cnn(input_shape=(224, 224, 3), num_classes=4):
#     inputs = Input(shape=input_shape)

#     # Convolutional Block 1
#     x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
#     x = layers.BatchNormalization()(x)
#     x = se_block(x)  # Add SE block for channel attention
#     x = layers.MaxPooling2D((2, 2), padding='same')(x)
#     x = layers.Dropout(0.2)(x)

#     # Convolutional Block 2
#     x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
#     x = layers.BatchNormalization()(x)
#     x = se_block(x)
#     x = layers.MaxPooling2D((2, 2), padding='same')(x)
#     x = layers.Dropout(0.3)(x)

#     # Convolutional Block 3
#     x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
#     x = layers.BatchNormalization()(x)
#     x = se_block(x)
#     x = layers.MaxPooling2D((2, 2), padding='same')(x)
#     x = layers.Dropout(0.4)(x)

#     # Flatten the output
#     x = layers.Flatten()(x)

#     # Fully Connected Block
#     x = layers.Dense(128, activation='relu', kernel_regularizer=l2(0.01))(x)
#     x = layers.BatchNormalization()(x)
#     x = layers.Dropout(0.5)(x)

#     x = layers.Dense(64, activation='relu', kernel_regularizer=l2(0.01))(x)
#     x = layers.BatchNormalization()(x)
#     x = layers.Dropout(0.5)(x)

#     # Output Layer
#     outputs = layers.Dense(num_classes, activation='softmax')(x)

#     # Define the Model
#     model = models.Model(inputs, outputs)

#     # Compile the Model
#     optimizer = Adam(learning_rate=1e-3)
#     model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

#     return model

# # Instantiate the model
# input_shape = (224, 224, 3)
# num_classes = 4
# model = build_attention_cnn(input_shape=input_shape, num_classes=num_classes)

# # Model Summary
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 224, 224, 3)         │             228 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ vgg16 (Functional)                   │ (None, 7, 7, 512)           │      14,714,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ last_conv (Conv2D)                   │ (None, 7, 7, 128)           │       1,638,528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 7, 7, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 7, 7, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 128)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1024)                │         132,096 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 1024)                │           4,096 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 512)                 │         524,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ root (Dense)                         │ (None, 4)                   │           2,052 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 17,019,560 (64.92 MB)
#  Trainable params: 2,301,288 (8.78 MB)
#  Non-trainable params: 14,718,272 (56.15 MB)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=15, verbose=5, min_lr=1e-3)
checkpoint = ModelCheckpoint('/kaggle/working//Custom_CNN_224_250[att].keras', monitor='val_accuracy', save_best_only=True)

# %%
import tensorflow as tf

tf.keras.backend.clear_session()
batch_size = 16
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, Y_train)).batch(batch_size).repeat().prefetch(1)
val_dataset = tf.data.Dataset.from_tensor_slices((X_val, Y_val)).batch(batch_size).repeat().prefetch(1)

# Calculate steps per epoch
steps_per_epoch = len(X_train) // batch_size
validation_steps = len(X_val) // batch_size

# Train the model
EPOCHS = 50
history = model.fit(
    train_dataset,
    steps_per_epoch=steps_per_epoch,
    epochs=EPOCHS,
    verbose=2,
    callbacks=[early_stopping, annealer, checkpoint],
    validation_data=val_dataset,
    validation_steps=validation_steps,
    shuffle=True
)
# Out:
# Epoch 1/50
# 43/43 - 48s - 1s/step - accuracy: 0.2980 - loss: 2.2820 - val_accuracy: 0.3090 - val_loss: 1.4570 - learning_rate: 1.0000e-04
# Epoch 2/50
# 43/43 - 41s - 942ms/step - accuracy: 0.4415 - loss: 1.7393 - val_accuracy: 0.3310 - val_loss: 1.4391 - learning_rate: 1.0000e-04
# Epoch 3/50
# 43/43 - 11s - 245ms/step - accuracy: 0.5190 - loss: 1.4507 - val_accuracy: 0.6127 - val_loss: 1.3335 - learning_rate: 1.0000e-04
# Epoch 4/50
# 43/43 - 11s - 250ms/step - accuracy: 0.5541 - loss: 1.3265 - val_accuracy: 0.6585 - val_loss: 1.1335 - learning_rate: 1.0000e-04
# Epoch 5/50
# 43/43 - 11s - 247ms/step - accuracy: 0.6155 - loss: 1.1263 - val_accuracy: 0.2746 - val_loss: 1.4028 - learning_rate: 1.0000e-04
# Epoch 6/50
# 43/43 - 11s - 254ms/step - accuracy: 0.6228 - loss: 1.1917 - val_accuracy: 0.3169 - val_loss: 1.4992 - learning_rate: 1.0000e-04
# Epoch 7/50
# 43/43 - 11s - 257ms/step - accuracy: 0.6170 - loss: 1.1258 - val_accuracy: 0.5352 - val_loss: 1.0709 - learning_rate: 1.0000e-04
# Epoch 8/50
# 43/43 - 11s - 267ms/step - accuracy: 0.6374 - loss: 1.0525 - val_accuracy: 0.6655 - val_loss: 0.6786 - learning_rate: 1.0000e-04
# Epoch 9/50
# 43/43 - 11s - 264ms/step - accuracy: 0.6550 - loss: 0.9699 - val_accuracy: 0.7218 - val_loss: 0.6420 - learning_rate: 1.0000e-04
# Epoch 10/50
# 43/43 - 11s - 249ms/step - accuracy: 0.6798 - loss: 1.0216 - val_accuracy: 0.5317 - val_loss: 1.3015 - learning_rate: 1.0000e-04
# Epoch 11/50
# 43/43 - 11s - 247ms/step - accuracy: 0.6813 - loss: 1.0014 - val_accuracy: 0.5352 - val_loss: 1.1802 - learning_rate: 1.0000e-04
# Epoch 12/50
# 43/43 - 11s - 261ms/step - accuracy: 0.6974 - loss: 0.8924 - val_accuracy: 0.7500 - val_loss: 0.5976 - learning_rate: 1.0000e-04
# Epoch 13/50
# 43/43 - 11s - 249ms/step - accuracy: 0.6959 - loss: 0.9232 - val_accuracy: 0.6408 - val_loss: 0.9082 - learning_rate: 1.0000e-04
# Epoch 14/50
# 43/43 - 11s - 252ms/step - accuracy: 0.7442 - loss: 0.8325 - val_accuracy: 0.6585 - val_loss: 0.9708 - learning_rate: 1.0000e-04
# Epoch 15/50
# 43/43 - 11s - 254ms/step - accuracy: 0.6959 - loss: 0.8773 - val_accuracy: 0.4789 - val_loss: 1.8670 - learning_rate: 1.0000e-04
# Epoch 16/50
# 43/43 - 11s - 266ms/step - accuracy: 0.7120 - loss: 0.7991 - val_accuracy: 0.7782 - val_loss: 0.5865 - learning_rate: 1.0000e-04
# Epoch 17/50
# 43/43 - 11s - 254ms/step - accuracy: 0.7135 - loss: 0.8372 - val_accuracy: 0.7042 - val_loss: 0.9101 - learning_rate: 1.0000e-04
# Epoch 18/50
# 43/43 - 11s - 255ms/step - accuracy: 0.7251 - loss: 0.7926 - val_accuracy: 0.7359 - val_loss: 0.7200 - learning_rate: 1.0000e-04
# Epoch 19/50
# 43/43 - 11s - 266ms/step - accuracy: 0.7120 - loss: 0.8581 - val_accuracy: 0.7958 - val_loss: 0.6033 - learning_rate: 1.0000e-04
# Epoch 20/50
# 43/43 - 11s - 255ms/step - accuracy: 0.7295 - loss: 0.7731 - val_accuracy: 0.6840 - val_loss: 0.9361 - learning_rate: 1.0000e-04
# Epoch 21/50
# 43/43 - 11s - 255ms/step - accuracy: 0.7602 - loss: 0.7082 - val_accuracy: 0.5880 - val_loss: 1.5203 - learning_rate: 1.0000e-04
# Epoch 22/50
# 43/43 - 11s - 255ms/step - accuracy: 0.7573 - loss: 0.6900 - val_accuracy: 0.6056 - val_loss: 1.1520 - learning_rate: 1.0000e-04
# Epoch 23/50
# 43/43 - 11s - 255ms/step - accuracy: 0.7427 - loss: 0.6759 - val_accuracy: 0.7430 - val_loss: 0.6027 - learning_rate: 1.0000e-04
# Epoch 24/50
# 43/43 - 11s - 255ms/step - accuracy: 0.7646 - loss: 0.6199 - val_accuracy: 0.7500 - val_loss: 0.6090 - learning_rate: 1.0000e-04
# Epoch 25/50
# 43/43 - 11s - 255ms/step - accuracy: 0.7880 - loss: 0.6290 - val_accuracy: 0.5880 - val_loss: 1.3548 - learning_rate: 1.0000e-04
# Epoch 26/50
# 43/43 - 11s - 254ms/step - accuracy: 0.7778 - loss: 0.6192 - val_accuracy: 0.5528 - val_loss: 1.6324 - learning_rate: 1.0000e-04
# Epoch 27/50
# 43/43 - 11s - 255ms/step - accuracy: 0.7690 - loss: 0.6961 - val_accuracy: 0.7570 - val_loss: 0.6948 - learning_rate: 1.0000e-04
# Epoch 28/50
# 43/43 - 11s - 267ms/step - accuracy: 0.7836 - loss: 0.5648 - val_accuracy: 0.8239 - val_loss: 0.4536 - learning_rate: 1.0000e-04
# Epoch 29/50
# 43/43 - 11s - 254ms/step - accuracy: 0.7822 - loss: 0.6247 - val_accuracy: 0.8063 - val_loss: 0.5960 - learning_rate: 1.0000e-04
# Epoch 30/50
# 43/43 - 11s - 254ms/step - accuracy: 0.7749 - loss: 0.6479 - val_accuracy: 0.7324 - val_loss: 0.6868 - learning_rate: 1.0000e-04
# Epoch 31/50
# 43/43 - 11s - 254ms/step - accuracy: 0.8012 - loss: 0.5968 - val_accuracy: 0.7394 - val_loss: 0.8423 - learning_rate: 1.0000e-04
# Epoch 32/50
# 43/43 - 11s - 255ms/step - accuracy: 0.7851 - loss: 0.6210 - val_accuracy: 0.8204 - val_loss: 0.5173 - learning_rate: 1.0000e-04
# Epoch 33/50
# 43/43 - 11s - 256ms/step - accuracy: 0.7822 - loss: 0.6086 - val_accuracy: 0.8204 - val_loss: 0.4467 - learning_rate: 1.0000e-04
# Epoch 34/50
# 43/43 - 11s - 254ms/step - accuracy: 0.7924 - loss: 0.5801 - val_accuracy: 0.7923 - val_loss: 0.6010 - learning_rate: 1.0000e-04
# Epoch 35/50
# 43/43 - 11s - 266ms/step - accuracy: 0.7895 - loss: 0.5950 - val_accuracy: 0.8415 - val_loss: 0.4891 - learning_rate: 1.0000e-04
# Epoch 36/50
# 43/43 - 11s - 254ms/step - accuracy: 0.7661 - loss: 0.6039 - val_accuracy: 0.7465 - val_loss: 0.7299 - learning_rate: 1.0000e-04
# Epoch 37/50
# 43/43 - 11s - 255ms/step - accuracy: 0.8158 - loss: 0.5298 - val_accuracy: 0.7289 - val_loss: 0.7893 - learning_rate: 1.0000e-04
# Epoch 38/50
# 43/43 - 11s - 255ms/step - accuracy: 0.8026 - loss: 0.5688 - val_accuracy: 0.8204 - val_loss: 0.5559 - learning_rate: 1.0000e-04
# Epoch 39/50
# 43/43 - 11s - 255ms/step - accuracy: 0.8099 - loss: 0.5146 - val_accuracy: 0.7083 - val_loss: 0.9032 - learning_rate: 1.0000e-04
# Epoch 40/50
# 43/43 - 11s - 255ms/step - accuracy: 0.7792 - loss: 0.6031 - val_accuracy: 0.6338 - val_loss: 1.7429 - learning_rate: 1.0000e-04
# Epoch 41/50
# 43/43 - 11s - 255ms/step - accuracy: 0.8085 - loss: 0.5208 - val_accuracy: 0.7430 - val_loss: 1.0366 - learning_rate: 1.0000e-04
# Epoch 42/50
# 43/43 - 11s - 255ms/step - accuracy: 0.7953 - loss: 0.5741 - val_accuracy: 0.6761 - val_loss: 1.0716 - learning_rate: 1.0000e-04
# Epoch 43/50
# 43/43 - 11s - 255ms/step - accuracy: 0.7851 - loss: 0.5514 - val_accuracy: 0.7711 - val_loss: 0.7761 - learning_rate: 1.0000e-04
# Epoch 44/50
# 43/43 - 11s - 255ms/step - accuracy: 0.8480 - loss: 0.4429 - val_accuracy: 0.7782 - val_loss: 0.7738 - learning_rate: 1.0000e-04
# Epoch 45/50
# 43/43 - 11s - 256ms/step - accuracy: 0.8256 - loss: 0.5169 - val_accuracy: 0.7852 - val_loss: 0.7431 - learning_rate: 1.0000e-04
# Epoch 46/50
# 43/43 - 11s - 255ms/step - accuracy: 0.8231 - loss: 0.4960 - val_accuracy: 0.8310 - val_loss: 0.4556 - learning_rate: 1.0000e-04
# Epoch 47/50
# 43/43 - 11s - 255ms/step - accuracy: 0.8304 - loss: 0.4733 - val_accuracy: 0.8310 - val_loss: 0.4548 - learning_rate: 1.0000e-04
# Epoch 48/50
# 43/43 - 11s - 255ms/step - accuracy: 0.8231 - loss: 0.4897 - val_accuracy: 0.8099 - val_loss: 0.4741 - learning_rate: 1.0000e-04

# %%
# model = load_model('../output/kaggle/working/model.h5')
final_loss, final_accuracy = model.evaluate(X_val, Y_val)
print('Final Loss: {}, Final Accuracy: {}'.format(final_loss, final_accuracy))
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 238ms/step - accuracy: 0.7984 - loss: 0.5255
# Final Loss: 0.4725649654865265, Final Accuracy: 0.8133333325386047

# %%
Y_pred = model.predict(X_val)

Y_pred = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_val, axis=1)

cm = confusion_matrix(Y_true, Y_pred)
plt.figure(figsize=(12, 12))
ax = sns.heatmap(cm, cmap=plt.cm.Greens, annot=True, square=True, xticklabels=disease_types, yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=20)
ax.set_xlabel('Predicted', fontsize=20)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 222ms/step
# Text(0.5, 192.72222222222217, 'Predicted')

# %%
from sklearn.metrics import classification_report, confusion_matrix
report = classification_report(Y_true, Y_pred, target_names=disease_types)
print(report)
# Out:
#                            precision    recall  f1-score   support
#
#    Bacterial Leaf Disease       0.72      0.61      0.66        83
# Fungal Brown Spot Disease       0.95      0.95      0.95        73
#                Dried Leaf       0.99      0.99      0.99        72
#              Healthy Leaf       0.63      0.74      0.68        72
#
#                  accuracy                           0.81       300
#                 macro avg       0.82      0.82      0.82       300
#              weighted avg       0.82      0.81      0.81       300

# %%
# loss plot
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# GRAD CAMM****

# %%
for layers in model.layers:
    print(layers.name)
# Out:
# input_layer_1
# conv2d
# vgg16
# last_conv
# batch_normalization
# dropout
# global_average_pooling2d
# batch_normalization_1
# dropout_1
# dense
# batch_normalization_2
# dropout_2
# dense_1
# batch_normalization_3
# dropout_3
# root

# %%
model1 = model

# %%
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
from tensorflow.keras import layers, models

from IPython.display import Image, display
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model, load_model # Import load_model here
from tensorflow.keras.preprocessing import image
import tensorflow.keras as keras
from tensorflow.keras.preprocessing.image import load_img, img_to_array

label_name = ['Bacterial Leaf Disease','Fungal Brown Spot Disease','Dried Leaf','Healthy Leaf']


img_path = '/kaggle/input/betel-dataset/Resized 224_250/Bacterial Leaf Disease/Bacterial_Leaf_Spot_Disease(86).jpg'
# img_path = '/content/110608-01-8356c-lg.jpg'

last_conv_layer_name = "last_conv"  # Ensure this matches your model's last conv layer
img_size = (224, 224)

# Preprocessing function
def preprocess_input(img_array):
    return img_array / 255.0

# Load the custom model

# Function to load and preprocess the image
def get_img_array(img_path, size):
    img = load_img(img_path, target_size=size)
    array = img_to_array(img)
    # Add a batch dimension
    return np.expand_dims(array, axis=0)

# Grad-CAM heatmap generation


def grad_cam_plus(model, img, layer_name="global_average_pooling2d", label_name=None, category_id=None):
    """Get a heatmap by Grad-CAM++."""
    # Do not expand dimensions here, as the input should already have a batch dimension
    img_tensor = img

    conv_layer = model.get_layer(layer_name)
    heatmap_model = Model([model.inputs], [conv_layer.output, model.output])

    with tf.GradientTape() as gtape1:
        with tf.GradientTape() as gtape2:
            with tf.GradientTape() as gtape3:
                conv_output, predictions = heatmap_model(img_tensor)
                if category_id is None:
                    category_id = np.argmax(predictions[0])
                if label_name is not None:
                    print(label_name[category_id])
                output = predictions[:, category_id]
                conv_first_grad = gtape3.gradient(output, conv_output)
            conv_second_grad = gtape2.gradient(conv_first_grad, conv_output)
        conv_third_grad = gtape1.gradient(conv_second_grad, conv_output)

    global_sum = np.sum(conv_output, axis=(0, 1, 2))

    alpha_num = conv_second_grad[0]
    alpha_denom = conv_second_grad[0] * 2.0 + conv_third_grad[0] * global_sum
    alpha_denom = np.where(alpha_denom != 0.0, alpha_denom, 1e-10)

    alphas = alpha_num / alpha_denom
    alpha_normalization_constant = np.sum(alphas, axis=(0, 1))
    alphas /= alpha_normalization_constant

    weights = np.maximum(conv_first_grad[0], 0.0)

    deep_linearization_weights = np.sum(weights * alphas, axis=(0, 1))
    grad_cam_map = np.sum(deep_linearization_weights * conv_output[0], axis=2)

    heatmap = np.maximum(grad_cam_map, 0)
    max_heat = np.max(heatmap)
    if max_heat == 0:
        max_heat = 1e-10
    heatmap /= max_heat

    return heatmap

# model1 = load_model("/content/drive/MyDrive/Betal Leaf_Project/Fresh Start/checkpoint/vgg16[clahe].keras")
# # model2 = load_model("/content/drive/MyDrive/Betal Leaf_Project/Fresh Start/Models/Checkpoints/vgg16_[edge].keras")
# # model3 = load_model("/content/drive/MyDrive/Betal Leaf_Project/Fresh Start/Models/Checkpoints/Best_densenet.keras")



img_array = get_img_array(img_path, size=img_size)  # This already has the batch dimension
img_array = preprocess_input(img_array)  # Normalize the image

# Predict the class of the image
preds1 = model1.predict(img_array)
# preds2 = model2.predict(img_array)
print("Predicted class probabilities:", preds1)
predicted_class = np.argmax(preds1[0])
print(f"Predicted class index: {predicted_class}")

# print("Predicted class probabilities:", preds2)
# predicted_class = np.argmax(preds2[0])
# print(f"Predicted class index: {predicted_class}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Predicted class probabilities: [[8.2071945e-02 1.1138468e-09 8.1092679e-08 9.1792798e-01]]
# Predicted class index: 3

# %%
# Generate the Grad-CAM++ heatmap
heatmap1 = grad_cam_plus(
    model1,
    img_array,
    layer_name=last_conv_layer_name,
    label_name=label_name,
    category_id=predicted_class,
)

# Display the heatmap
plt.matshow(heatmap1)
plt.title("Grad-CAM++ Heatmap")
plt.show()
# Out:
# Healthy Leaf

# %%
def superimpose_heatmap(heatmap, img_path, alpha=0.5):
    img = load_img(img_path)
    img = img_to_array(img)

    # Resize heatmap to match image size
    heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))

    # Convert heatmap to RGB
    heatmap = np.uint8(255 * heatmap)
    heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)

    # Superimpose the heatmap on the image
    superimposed_img = heatmap * alpha + img
    superimposed_img = np.uint8(superimposed_img / np.max(superimposed_img) * 255)
    return superimposed_img

# Generate the superimposed heatmap image
superimposed_img = superimpose_heatmap(heatmap1, img_path)

# Display the superimposed image
plt.imshow(superimposed_img.astype("uint8"))
plt.axis("off")
plt.title("Grad-CAM Superimposed")
plt.show()

# %%
def superimpose_heatmap(heatmap, img_path, alpha=0.5):
    img = load_img(img_path)
    img = img_to_array(img)

    # Resize heatmap to match image size
    heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))

    # Convert heatmap to RGB
    heatmap = np.uint8(255 * heatmap)
    heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)

    # Superimpose the heatmap on the image
    superimposed_img = heatmap * alpha + img
    superimposed_img = np.uint8(superimposed_img / np.max(superimposed_img) * 255)
    return superimposed_img

# Generate the superimposed heatmap image
superimposed_img = superimpose_heatmap(heatmap1, img_path)

# Display the superimposed image
plt.imshow(superimposed_img.astype("uint8"))
plt.axis("off")
plt.title("Grad-CAM Superimposed")
plt.show()

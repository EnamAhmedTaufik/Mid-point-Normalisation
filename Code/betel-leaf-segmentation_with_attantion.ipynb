# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
import numpy as np
from sklearn.model_selection import train_test_split
from skimage.transform import resize
import os
import cv2
from PIL import Image as PILImage
import keras.backend as K
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import MeanIoU

# %%
# !pip install scikit-image --quiet
# Out:
# /usr/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()

# %%
IMG_HEIGHT = 256
IMG_WIDTH = 256
IMG_CHANNEL = 3
BATCH_SIZE = 8
EPOCHS = 150
SEED = 13
smooth = 1.0

# %%
# Define directories for images and masks
image_directory = '/kaggle/input/betel-seg/Dataset for Segmentation/images'  # Update this path to your actual image directory
mask_directory = '/kaggle/input/betel-seg/Dataset for Segmentation/masks'  # Update this path to your actual mask directory

# %%
images = sorted(os.listdir(image_directory))
masks = sorted(os.listdir(mask_directory))

# %%
# Print image and corresponding mask names to check alignment
for i, image_name in enumerate(images[:5]):  # Checking first 5 examples
    mask_name = masks[i]
    print(f"Image: {image_name} -> Mask: {mask_name}")
# Out:
# Image: Bacterial_Leaf_Spot_Disease(1).jpg -> Mask: Bacterial_Leaf_Spot_Disease(1).png
# Image: Bacterial_Leaf_Spot_Disease(10).jpg -> Mask: Bacterial_Leaf_Spot_Disease(10).png
# Image: Bacterial_Leaf_Spot_Disease(100).jpg -> Mask: Bacterial_Leaf_Spot_Disease(100).png
# Image: Bacterial_Leaf_Spot_Disease(101).jpg -> Mask: Bacterial_Leaf_Spot_Disease(101).png
# Image: Bacterial_Leaf_Spot_Disease(102).jpg -> Mask: Bacterial_Leaf_Spot_Disease(102).png

# %%
image_basenames = [os.path.splitext(image)[0] for image in images]
mask_basenames = [os.path.splitext(mask)[0] for mask in masks]

# Check for missing masks
missing_masks = [image for image in image_basenames if image not in mask_basenames]

# Check for extra masks
extra_masks = [mask for mask in mask_basenames if mask not in image_basenames]

# Output results
print(f"Total images: {len(images)}")
print(f"Total masks: {len(masks)}")
print(f"Images missing masks: {len(missing_masks)}")
for missing in missing_masks:
    print(f"Missing mask for image: {missing}")

if extra_masks:
    print(f"\nExtra masks found ({len(extra_masks)}):")
    for extra in extra_masks:
        print(f"Extra mask without an image: {extra}")
# Out:
# Total images: 992
# Total masks: 971
# Images missing masks: 22
# Missing mask for image: Bacterial_Leaf_Spot_Disease(167)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(193)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(236)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(247)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(33)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(53)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(54)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(61)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(62)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(66)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(71)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(81)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(82)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(85)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(88)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(93)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(94)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(95)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(97)
# Missing mask for image: Bacterial_Leaf_Spot_Disease(98)
# Missing mask for image: Healthy_Leaf(102)
# Missing mask for image: Healthy_Leaf(103)
#
# Extra masks found (1):
# Extra mask without an image: Fungal_Brown_Spot_Disease-64-_jpg.rf.5a379f0a955b73ce9372a460b2c2b5fb(1)

# %%
# Filter out images without matching masks
valid_images = [image for image in images if os.path.splitext(image)[0] in mask_basenames]

# Filter out masks without matching images (optional, if needed)
valid_masks = [mask for mask in masks if os.path.splitext(mask)[0] in image_basenames]

# Output results
print(f"Total valid images for training: {len(valid_images)}")
print(f"Total valid masks for training: {len(valid_masks)}")

# # For confirmation (optional)
# for image, mask in zip(valid_images, valid_masks):
#     print(f"Image: {image} | Mask: {mask}")
# Out:
# Total valid images for training: 970
# Total valid masks for training: 970

# %%
# from skimage.transform import resize
# import os
# import numpy as np
# from PIL import Image as PILImage
# import cv2
# from IPython.display import Image, display  # Import for displaying images in Jupyter

# # Define the size to which all images and masks will be resized
# IMG_HEIGHT = 256
# IMG_WIDTH = 256
# IMG_CHANNEL = 3  # For RGB images

# # Initialize lists to store the images and masks
# image_dataset = []
# mask_dataset = []

# # Ensure images and masks are sorted
# images = sorted(os.listdir(image_directory))
# masks = sorted(os.listdir(mask_directory))

# # Create a mapping of image filenames to mask filenames
# image_mask_map = {}
# for image_name in images:
#     if image_name.endswith('.jpg') or image_name.endswith('.png') or image_name.endswith('.tif'):
#         base_name = os.path.splitext(image_name)[0]
#         corresponding_mask = f"{base_name}.png"  # Assuming masks are in .png format
#         image_mask_map[image_name] = corresponding_mask

# # Load and process the images and masks
# for image_name, mask_name in image_mask_map.items():
#     if mask_name in masks:
#         # Read and process image
#         image_path = os.path.join(image_directory, image_name)
#         image = cv2.imread(image_path)
#         image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
#         image = resize(image, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)  # Resize using skimage
#         image = image.astype(np.uint8)  # Ensure the dtype is uint8
#         image_dataset.append(image)

#         # Display the image using IPython's Image
#         #display(PILImage.fromarray(image))  # For visualization in Jupyter

#         # Read and process mask
#         mask_path = os.path.join(mask_directory, mask_name)
#         mask = cv2.imread(mask_path, 0)  # Read in grayscale
#         mask = resize(mask, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)  # Resize using skimage
#         mask = np.expand_dims(mask, axis=-1)  # Add channel dimension (to get shape (H, W, 1))
#         mask = mask.astype(bool)  # Use built-in Python bool type
#         mask_dataset.append(mask)



# # Convert lists to NumPy arrays
# image_dataset = np.array(image_dataset)
# mask_dataset = np.array(mask_dataset)

# # Normalize the images to the range [0, 1]
# image_dataset = image_dataset / 255.0

# # Ensure images and masks match in length
# assert len(image_dataset) == len(mask_dataset), "Number of images and masks don't match!"

# # Print a few to check they are paired correctly
# for i in range(5):
#     print(f"Image {i}: {images[i]} -> Mask {i}: {list(image_mask_map.values())[i]}")

# print(f"Image dataset shape: {image_dataset.shape}")
# print(f"Mask dataset shape: {mask_dataset.shape}")

# %%
# np.save('/content/drive/MyDrive/Betal Leaf_Project/Fresh Start/Models/Checkpoints/image_dataset.npy', image_dataset)
# np.save('/content/drive/MyDrive/Betal Leaf_Project/Fresh Start/Models/Checkpoints/mask_dataset.npy', mask_dataset)

# To load them back
image_dataset = np.load('/kaggle/input/np-arrays/image_dataset.npy')
mask_dataset = np.load('/kaggle/input/np-arrays/mask_dataset.npy')

# %%
from matplotlib import pyplot as plt
# Visualize the first image and its corresponding binary mask
plt.figure(figsize=(5, 5))
plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(image_dataset[0])

plt.subplot(1, 2, 2)
plt.title('Binary Mask')
plt.imshow(mask_dataset[0], cmap='gray')

plt.show()

# %%
x_train, x_val, y_train, y_val = train_test_split(
    image_dataset, mask_dataset, test_size=0.45, random_state=SEED, shuffle=True
)
# Check shapes
print(f"Training images shape: {x_train.shape}")  # Should be (num_samples, 128, 128, 3)
print(f"Training masks shape: {y_train.shape}")   # Should be (num_samples, 128, 128, 1)
print(f"Validation images shape: {x_val.shape}")  # Should be (num_samples, 128, 128, 3)
print(f"Validation masks shape: {y_val.shape}")   # Should be (num_samples, 128, 128, 1)
# Out:
# Training images shape: (533, 256, 256, 3)
# Training masks shape: (533, 256, 256, 1)
# Validation images shape: (437, 256, 256, 3)
# Validation masks shape: (437, 256, 256, 1)

# %%
# Training data augmentation
data_gen_args = dict(rotation_range=90.,
                         width_shift_range=0.2,
                         height_shift_range=0.2,
                         shear_range=0.3,
                         zoom_range=0.3,
                         horizontal_flip=True,
                         vertical_flip=True,
                         fill_mode='reflect')

# Apply augmentation only for training data
X_datagen = ImageDataGenerator(**data_gen_args)
Y_datagen = ImageDataGenerator(**data_gen_args)

# No augmentation for validation data
X_datagen_val = ImageDataGenerator()  # Default, no augmentation
Y_datagen_val = ImageDataGenerator()  # Default, no augmentation

# Fitting generators for training data
X_datagen.fit(x_train, augment=True, seed=13)
Y_datagen.fit(y_train, augment=True, seed=13)

# Fitting generators for validation data (no augmentation)
X_datagen_val.fit(x_val, augment=False, seed=13)
Y_datagen_val.fit(y_val, augment=False, seed=13)

# Creating the data generators
X_train_augmented = X_datagen.flow(x_train, batch_size=8, shuffle=True, seed=13)
Y_train_augmented = Y_datagen.flow(y_train, batch_size=8, shuffle=True, seed=13)

# Validation data without augmentation
X_train_augmented_val = X_datagen_val.flow(x_val, batch_size=8, shuffle=False, seed=13)
Y_train_augmented_val = Y_datagen_val.flow(y_val, batch_size=8, shuffle=False, seed=13)

# Zip the augmented generators for training and validation
train_generator = zip(X_train_augmented, Y_train_augmented)
val_generator = zip(X_train_augmented_val, Y_train_augmented_val)

# %%
import matplotlib.pyplot as plt

def visualize_augmentation(generator, num_samples=5):
    plt.figure(figsize=(12, 8))
    for i in range(num_samples):
        batch = next(generator)
        images = batch[0]
        masks = batch[1]

        plt.subplot(num_samples, 2, 2*i + 1)
        plt.imshow(images[0])  # Display the first image of the batch
        plt.title('Augmented Image')
        plt.axis('off')

        plt.subplot(num_samples, 2, 2*i + 2)
        plt.imshow(masks[0].squeeze(), cmap='gray')  # Display the first mask of the batch
        plt.title('Augmented Mask')
        plt.axis('off')

    plt.show()

# Visualize augmented training images and masks
visualize_augmentation(train_generator, num_samples=5)

# %%
import tensorflow as tf
from tensorflow.keras.losses import CategoricalCrossentropy

# Dice loss function for multiclass segmentation
def dice_loss_multiclass(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    # One-hot encode y_pred if it's not already
    if y_pred.shape[-1] != y_true.shape[-1]:
        y_pred = tf.one_hot(tf.argmax(y_pred, axis=-1), depth=y_true.shape[-1])

    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    denominator = tf.reduce_sum(y_true + y_pred, axis=[1, 2, 3])
    dice = tf.reduce_mean((numerator + smooth) / (denominator + smooth), axis=0)
    return 1 - dice

# Combined loss: categorical cross-entropy + dice loss
def combined_multiclass_loss(y_true, y_pred):
    categorical_loss = CategoricalCrossentropy(from_logits=False)
    return categorical_loss(y_true, y_pred) + dice_loss_multiclass(y_true, y_pred)

# IOU metric for multiclass segmentation
def iou_multiclass(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)

    # Convert y_pred to one-hot encoding if necessary
    if y_pred.shape[-1] != y_true.shape[-1]:
        y_pred = tf.one_hot(tf.argmax(y_pred, axis=-1), depth=y_true.shape[-1])

    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true + y_pred, axis=[1, 2, 3]) - intersection
    iou = tf.reduce_mean((intersection + smooth) / (union + smooth), axis=0)
    return iou

# Dice coefficient metric for multiclass segmentation
def dice_coef_multiclass(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)

    # Convert y_pred to one-hot encoding if necessary
    if y_pred.shape[-1] != y_true.shape[-1]:
        y_pred = tf.one_hot(tf.argmax(y_pred, axis=-1), depth=y_true.shape[-1])

    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    denominator = tf.reduce_sum(y_true + y_pred, axis=[1, 2, 3])
    dice = tf.reduce_mean((numerator + smooth) / (denominator + smooth), axis=0)
    return dice

# %%
from keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, Dropout, MaxPooling2D, Conv2DTranspose, concatenate, BatchNormalization, Activation, GlobalAveragePooling2D, Reshape, Dense, Multiply
from keras.regularizers import l2

SIZE = 256

def se_block(input_tensor, reduction_ratio=16):
    filters = input_tensor.shape[-1]
    se = GlobalAveragePooling2D()(input_tensor)
    se = Reshape((1, 1, filters))(se)
    se = Dense(filters // reduction_ratio, activation='relu')(se)
    se = Dense(filters, activation='sigmoid')(se)
    se = Multiply()([input_tensor, se])
    return se

def simple_unet_model_l2(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS, reg_value=0.001):
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))

    # Contraction path
    c1 = Conv2D(16, (3, 3), kernel_initializer='he_normal', padding='same', kernel_regularizer=l2(reg_value))(inputs)
    c1 = BatchNormalization()(c1)
    c1 = Activation('relu')(c1)
    c1 = Dropout(0.1)(c1)
    c1 = Conv2D(16, (3, 3), kernel_initializer='he_normal', padding='same', kernel_regularizer=l2(reg_value))(c1)
    c1 = BatchNormalization()(c1)
    c1 = Activation('relu')(c1)
    c1 = se_block(c1)  # Add SE block
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(32, (3, 3), kernel_initializer='he_normal', padding='same', kernel_regularizer=l2(reg_value))(p1)
    c2 = BatchNormalization()(c2)
    c2 = Activation('relu')(c2)
    c2 = Dropout(0.1)(c2)
    c2 = Conv2D(32, (3, 3), kernel_initializer='he_normal', padding='same', kernel_regularizer=l2(reg_value))(c2)
    c2 = BatchNormalization()(c2)
    c2 = Activation('relu')(c2)
    c2 = se_block(c2)  # Add SE block
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(64, (3, 3), kernel_initializer='he_normal', padding='same', kernel_regularizer=l2(reg_value))(p2)
    c3 = BatchNormalization()(c3)
    c3 = Activation('relu')(c3)
    c3 = Dropout(0.2)(c3)
    c3 = Conv2D(64, (3, 3), kernel_initializer='he_normal', padding='same', kernel_regularizer=l2(reg_value))(c3)
    c3 = BatchNormalization()(c3)
    c3 = Activation('relu')(c3)
    c3 = se_block(c3)  # Add SE block

    # Expansive path
    u6 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c3)
    u6 = concatenate([u6, c2])
    c6 = Conv2D(32, (3, 3), kernel_initializer='he_normal', padding='same', kernel_regularizer=l2(reg_value))(u6)
    c6 = BatchNormalization()(c6)
    c6 = Activation('relu')(c6)
    c6 = Dropout(0.1)(c6)
    c6 = se_block(c6)  # Add SE block (optional)

    u7 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = concatenate([u7, c1])
    c7 = Conv2D(16, (3, 3), kernel_initializer='he_normal', padding='same', kernel_regularizer=l2(reg_value))(u7)
    c7 = BatchNormalization()(c7)
    c7 = Activation('relu')(c7)
    c7 = Dropout(0.1)(c7)
    c7 = se_block(c7)  # Add SE block (optional)

    outputs = Conv2D(4, (1, 1), activation='sigmoid')(c7)

    # Create the model
    model = Model(inputs=[inputs], outputs=[outputs])

    return model

# Define the input shape
input_shape = (SIZE, SIZE, 3)
model = simple_unet_model_l2(SIZE, SIZE, 3)

# Print the model summary
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 256, 256, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 256, 256, 16)   │            448 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 256, 256, 16)   │             64 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation (Activation)   │ (None, 256, 256, 16)   │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 256, 256, 16)   │              0 │ activation[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 256, 256, 16)   │          2,320 │ dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 256, 256, 16)   │             64 │ conv2d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_1 (Activation) │ (None, 256, 256, 16)   │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 16)             │              0 │ activation_1[0][0]     │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape (Reshape)         │ (None, 1, 1, 16)       │              0 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 1, 1, 1)        │             17 │ reshape[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 1, 1, 16)       │             32 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply (Multiply)       │ (None, 256, 256, 16)   │              0 │ activation_1[0][0],    │
# │                           │                        │                │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 128, 128, 16)   │              0 │ multiply[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 128, 128, 32)   │          4,640 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 128, 128, 32)   │            128 │ conv2d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_2 (Activation) │ (None, 128, 128, 32)   │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 128, 128, 32)   │              0 │ activation_2[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 128, 128, 32)   │          9,248 │ dropout_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 128, 128, 32)   │            128 │ conv2d_3[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_3 (Activation) │ (None, 128, 128, 32)   │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 32)             │              0 │ activation_3[0][0]     │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_1 (Reshape)       │ (None, 1, 1, 32)       │              0 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 1, 1, 2)        │             66 │ reshape_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 1, 1, 32)       │             96 │ dense_2[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_1 (Multiply)     │ (None, 128, 128, 32)   │              0 │ activation_3[0][0],    │
# │                           │                        │                │ dense_3[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 64, 64, 32)     │              0 │ multiply_1[0][0]       │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 64, 64, 64)     │         18,496 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 64, 64, 64)     │            256 │ conv2d_4[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_4 (Activation) │ (None, 64, 64, 64)     │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_2 (Dropout)       │ (None, 64, 64, 64)     │              0 │ activation_4[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 64, 64, 64)     │         36,928 │ dropout_2[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 64, 64, 64)     │            256 │ conv2d_5[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_5 (Activation) │ (None, 64, 64, 64)     │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 64)             │              0 │ activation_5[0][0]     │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_2 (Reshape)       │ (None, 1, 1, 64)       │              0 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 1, 1, 4)        │            260 │ reshape_2[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_5 (Dense)           │ (None, 1, 1, 64)       │            320 │ dense_4[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_2 (Multiply)     │ (None, 64, 64, 64)     │              0 │ activation_5[0][0],    │
# │                           │                        │                │ dense_5[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 128, 128, 32)   │          8,224 │ multiply_2[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 128, 128, 64)   │              0 │ conv2d_transpose[0][0… │
# │                           │                        │                │ multiply_1[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 128, 128, 32)   │         18,464 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 128, 128, 32)   │            128 │ conv2d_6[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_6 (Activation) │ (None, 128, 128, 32)   │              0 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_3 (Dropout)       │ (None, 128, 128, 32)   │              0 │ activation_6[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 32)             │              0 │ dropout_3[0][0]        │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_3 (Reshape)       │ (None, 1, 1, 32)       │              0 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_6 (Dense)           │ (None, 1, 1, 2)        │             66 │ reshape_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_7 (Dense)           │ (None, 1, 1, 32)       │             96 │ dense_6[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_3 (Multiply)     │ (None, 128, 128, 32)   │              0 │ dropout_3[0][0],       │
# │                           │                        │                │ dense_7[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 256, 256, 16)   │          2,064 │ multiply_3[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 256, 256, 32)   │              0 │ conv2d_transpose_1[0]… │
# │ (Concatenate)             │                        │                │ multiply[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 256, 256, 16)   │          4,624 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 256, 256, 16)   │             64 │ conv2d_7[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_7 (Activation) │ (None, 256, 256, 16)   │              0 │ batch_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_4 (Dropout)       │ (None, 256, 256, 16)   │              0 │ activation_7[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 16)             │              0 │ dropout_4[0][0]        │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_4 (Reshape)       │ (None, 1, 1, 16)       │              0 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_8 (Dense)           │ (None, 1, 1, 1)        │             17 │ reshape_4[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_9 (Dense)           │ (None, 1, 1, 16)       │             32 │ dense_8[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_4 (Multiply)     │ (None, 256, 256, 16)   │              0 │ dropout_4[0][0],       │
# │                           │                        │                │ dense_9[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 256, 256, 4)    │             68 │ multiply_4[0][0]       │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 107,614 (420.37 KB)
#  Trainable params: 107,070 (418.24 KB)
#  Non-trainable params: 544 (2.12 KB)

# %%
def combined_generator(image_gen, mask_gen):
    while True:
        X = image_gen.__next__()
        Y = mask_gen.__next__()
        if X.shape[0] == Y.shape[0]:

            Y = tf.one_hot(tf.cast(Y, tf.int32), depth=4)
            Y = tf.squeeze(Y, axis=3)
            yield X, Y

# Create TensorFlow datasets
train_dataset = tf.data.Dataset.from_generator(
    lambda: combined_generator(X_train_augmented, Y_train_augmented),
    output_signature=(
        tf.TensorSpec(shape=(None, SIZE, SIZE, 3), dtype=tf.float32),
        tf.TensorSpec(shape=(None, SIZE, SIZE, 4), dtype=tf.float32)  # Changed to 4 channels
    )
)

val_dataset = tf.data.Dataset.from_generator(
    lambda: combined_generator(X_train_augmented_val, Y_train_augmented_val),
    output_signature=(
        tf.TensorSpec(shape=(None, SIZE, SIZE, 3), dtype=tf.float32),
        tf.TensorSpec(shape=(None, SIZE, SIZE, 4), dtype=tf.float32)  # Changed to 4 channels
    )
)

# Instantiate the model
model = simple_unet_model_l2(SIZE, SIZE, 3)

# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
              loss=combined_multiclass_loss,
              metrics=['accuracy', dice_coef_multiclass, iou_multiclass])

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', patience=15, verbose=1, factor=0.5, min_lr=1e-3)
checkpoint = ModelCheckpoint('/kaggle/working//unet_original.keras', monitor='val_loss', verbose=1, save_best_only=True)

# Train the model
EPOCHS = 100
BATCH_SIZE = 8
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=[early_stopping, checkpoint, reduce_lr],
    steps_per_epoch=len(x_train) // BATCH_SIZE,
    validation_steps=len(x_val) // BATCH_SIZE
)
# Out:
# Epoch 1/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.2565 - dice_coef_multiclass: 0.3442 - iou_multiclass: 0.2081 - loss: 2.6175
# Epoch 1: val_loss improved from inf to 2.49831, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 57s 444ms/step - accuracy: 0.2570 - dice_coef_multiclass: 0.3443 - iou_multiclass: 0.2081 - loss: 2.6168 - val_accuracy: 0.4697 - val_dice_coef_multiclass: 0.3447 - val_iou_multiclass: 0.2082 - val_loss: 2.4983 - learning_rate: 1.0000e-04
# Epoch 2/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.3946 - dice_coef_multiclass: 0.3628 - iou_multiclass: 0.2220 - loss: 2.4263
# Epoch 2: val_loss improved from 2.49831 to 2.35656, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 12s 184ms/step - accuracy: 0.3950 - dice_coef_multiclass: 0.3629 - iou_multiclass: 0.2220 - loss: 2.4257 - val_accuracy: 0.5607 - val_dice_coef_multiclass: 0.3612 - val_iou_multiclass: 0.2206 - val_loss: 2.3566 - learning_rate: 1.0000e-04
# Epoch 3/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.5137 - dice_coef_multiclass: 0.3821 - iou_multiclass: 0.2368 - loss: 2.2608
# Epoch 3: val_loss improved from 2.35656 to 2.16862, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.5138 - dice_coef_multiclass: 0.3821 - iou_multiclass: 0.2369 - loss: 2.2605 - val_accuracy: 0.6035 - val_dice_coef_multiclass: 0.3881 - val_iou_multiclass: 0.2416 - val_loss: 2.1686 - learning_rate: 1.0000e-04
# Epoch 4/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.5865 - dice_coef_multiclass: 0.3899 - iou_multiclass: 0.2428 - loss: 2.1859
# Epoch 4: val_loss improved from 2.16862 to 2.01739, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 151ms/step - accuracy: 0.5870 - dice_coef_multiclass: 0.3900 - iou_multiclass: 0.2429 - loss: 2.1850 - val_accuracy: 0.6273 - val_dice_coef_multiclass: 0.4157 - val_iou_multiclass: 0.2643 - val_loss: 2.0174 - learning_rate: 1.0000e-04
# Epoch 5/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.6607 - dice_coef_multiclass: 0.4033 - iou_multiclass: 0.2536 - loss: 2.0812
# Epoch 5: val_loss improved from 2.01739 to 1.90681, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 151ms/step - accuracy: 0.6609 - dice_coef_multiclass: 0.4034 - iou_multiclass: 0.2536 - loss: 2.0806 - val_accuracy: 0.6990 - val_dice_coef_multiclass: 0.4338 - val_iou_multiclass: 0.2794 - val_loss: 1.9068 - learning_rate: 1.0000e-04
# Epoch 6/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.7052 - dice_coef_multiclass: 0.4166 - iou_multiclass: 0.2643 - loss: 1.9817
# Epoch 6: val_loss improved from 1.90681 to 1.82692, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 156ms/step - accuracy: 0.7052 - dice_coef_multiclass: 0.4166 - iou_multiclass: 0.2644 - loss: 1.9813 - val_accuracy: 0.7437 - val_dice_coef_multiclass: 0.4433 - val_iou_multiclass: 0.2871 - val_loss: 1.8269 - learning_rate: 1.0000e-04
# Epoch 7/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.5433 - dice_coef_multiclass: 0.3917 - iou_multiclass: 0.2448 - loss: 2.1766
# Epoch 7: val_loss did not improve from 1.82692
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 150ms/step - accuracy: 0.5435 - dice_coef_multiclass: 0.3918 - iou_multiclass: 0.2448 - loss: 2.1763 - val_accuracy: 0.7511 - val_dice_coef_multiclass: 0.4261 - val_iou_multiclass: 0.2717 - val_loss: 1.8818 - learning_rate: 1.0000e-04
# Epoch 8/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.6553 - dice_coef_multiclass: 0.4137 - iou_multiclass: 0.2619 - loss: 1.9882
# Epoch 8: val_loss improved from 1.82692 to 1.73468, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 153ms/step - accuracy: 0.6561 - dice_coef_multiclass: 0.4139 - iou_multiclass: 0.2620 - loss: 1.9869 - val_accuracy: 0.7660 - val_dice_coef_multiclass: 0.4515 - val_iou_multiclass: 0.2934 - val_loss: 1.7347 - learning_rate: 1.0000e-04
# Epoch 9/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.7329 - dice_coef_multiclass: 0.4356 - iou_multiclass: 0.2798 - loss: 1.8345
# Epoch 9: val_loss improved from 1.73468 to 1.67375, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 149ms/step - accuracy: 0.7330 - dice_coef_multiclass: 0.4356 - iou_multiclass: 0.2798 - loss: 1.8342 - val_accuracy: 0.7842 - val_dice_coef_multiclass: 0.4609 - val_iou_multiclass: 0.3013 - val_loss: 1.6737 - learning_rate: 1.0000e-04
# Epoch 10/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.7124 - dice_coef_multiclass: 0.4385 - iou_multiclass: 0.2824 - loss: 1.8190
# Epoch 10: val_loss improved from 1.67375 to 1.64219, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 151ms/step - accuracy: 0.7129 - dice_coef_multiclass: 0.4386 - iou_multiclass: 0.2825 - loss: 1.8182 - val_accuracy: 0.7782 - val_dice_coef_multiclass: 0.4660 - val_iou_multiclass: 0.3059 - val_loss: 1.6422 - learning_rate: 1.0000e-04
# Epoch 11/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.7212 - dice_coef_multiclass: 0.4461 - iou_multiclass: 0.2889 - loss: 1.7678
# Epoch 11: val_loss improved from 1.64219 to 1.60854, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 150ms/step - accuracy: 0.7215 - dice_coef_multiclass: 0.4462 - iou_multiclass: 0.2890 - loss: 1.7672 - val_accuracy: 0.7919 - val_dice_coef_multiclass: 0.4698 - val_iou_multiclass: 0.3091 - val_loss: 1.6085 - learning_rate: 1.0000e-04
# Epoch 12/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.7455 - dice_coef_multiclass: 0.4550 - iou_multiclass: 0.2961 - loss: 1.7100
# Epoch 12: val_loss improved from 1.60854 to 1.57770, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 151ms/step - accuracy: 0.7456 - dice_coef_multiclass: 0.4550 - iou_multiclass: 0.2962 - loss: 1.7095 - val_accuracy: 0.7902 - val_dice_coef_multiclass: 0.4745 - val_iou_multiclass: 0.3132 - val_loss: 1.5777 - learning_rate: 1.0000e-04
# Epoch 13/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.7342 - dice_coef_multiclass: 0.4594 - iou_multiclass: 0.3002 - loss: 1.6910
# Epoch 13: val_loss improved from 1.57770 to 1.53804, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 153ms/step - accuracy: 0.7345 - dice_coef_multiclass: 0.4595 - iou_multiclass: 0.3003 - loss: 1.6905 - val_accuracy: 0.8053 - val_dice_coef_multiclass: 0.4807 - val_iou_multiclass: 0.3184 - val_loss: 1.5380 - learning_rate: 1.0000e-04
# Epoch 14/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.7419 - dice_coef_multiclass: 0.4647 - iou_multiclass: 0.3046 - loss: 1.6617
# Epoch 14: val_loss improved from 1.53804 to 1.51377, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 150ms/step - accuracy: 0.7422 - dice_coef_multiclass: 0.4647 - iou_multiclass: 0.3047 - loss: 1.6611 - val_accuracy: 0.8030 - val_dice_coef_multiclass: 0.4845 - val_iou_multiclass: 0.3217 - val_loss: 1.5138 - learning_rate: 1.0000e-04
# Epoch 15/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.7313 - dice_coef_multiclass: 0.4700 - iou_multiclass: 0.3091 - loss: 1.6335
# Epoch 15: val_loss improved from 1.51377 to 1.48753, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 152ms/step - accuracy: 0.7318 - dice_coef_multiclass: 0.4701 - iou_multiclass: 0.3092 - loss: 1.6328 - val_accuracy: 0.8055 - val_dice_coef_multiclass: 0.4898 - val_iou_multiclass: 0.3263 - val_loss: 1.4875 - learning_rate: 1.0000e-04
# Epoch 16/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.7573 - dice_coef_multiclass: 0.4783 - iou_multiclass: 0.3164 - loss: 1.5856
# Epoch 16: val_loss improved from 1.48753 to 1.43653, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 11s 161ms/step - accuracy: 0.7573 - dice_coef_multiclass: 0.4783 - iou_multiclass: 0.3164 - loss: 1.5853 - val_accuracy: 0.8043 - val_dice_coef_multiclass: 0.5008 - val_iou_multiclass: 0.3361 - val_loss: 1.4365 - learning_rate: 1.0000e-04
# Epoch 17/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.7371 - dice_coef_multiclass: 0.4826 - iou_multiclass: 0.3201 - loss: 1.5756
# Epoch 17: val_loss improved from 1.43653 to 1.40321, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 155ms/step - accuracy: 0.7374 - dice_coef_multiclass: 0.4827 - iou_multiclass: 0.3202 - loss: 1.5749 - val_accuracy: 0.8105 - val_dice_coef_multiclass: 0.5054 - val_iou_multiclass: 0.3400 - val_loss: 1.4032 - learning_rate: 1.0000e-04
# Epoch 18/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.7753 - dice_coef_multiclass: 0.4956 - iou_multiclass: 0.3313 - loss: 1.4820
# Epoch 18: val_loss improved from 1.40321 to 1.39804, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 153ms/step - accuracy: 0.7754 - dice_coef_multiclass: 0.4957 - iou_multiclass: 0.3313 - loss: 1.4818 - val_accuracy: 0.8019 - val_dice_coef_multiclass: 0.5083 - val_iou_multiclass: 0.3423 - val_loss: 1.3980 - learning_rate: 1.0000e-04
# Epoch 19/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.7644 - dice_coef_multiclass: 0.4965 - iou_multiclass: 0.3323 - loss: 1.4936
# Epoch 19: val_loss improved from 1.39804 to 1.35053, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 156ms/step - accuracy: 0.7649 - dice_coef_multiclass: 0.4966 - iou_multiclass: 0.3324 - loss: 1.4927 - val_accuracy: 0.8049 - val_dice_coef_multiclass: 0.5179 - val_iou_multiclass: 0.3512 - val_loss: 1.3505 - learning_rate: 1.0000e-04
# Epoch 20/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.7781 - dice_coef_multiclass: 0.5058 - iou_multiclass: 0.3407 - loss: 1.4484
# Epoch 20: val_loss improved from 1.35053 to 1.31326, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 149ms/step - accuracy: 0.7781 - dice_coef_multiclass: 0.5059 - iou_multiclass: 0.3407 - loss: 1.4480 - val_accuracy: 0.7981 - val_dice_coef_multiclass: 0.5275 - val_iou_multiclass: 0.3601 - val_loss: 1.3133 - learning_rate: 1.0000e-04
# Epoch 21/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.7666 - dice_coef_multiclass: 0.5090 - iou_multiclass: 0.3438 - loss: 1.4382
# Epoch 21: val_loss did not improve from 1.31326
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.7669 - dice_coef_multiclass: 0.5091 - iou_multiclass: 0.3439 - loss: 1.4375 - val_accuracy: 0.7834 - val_dice_coef_multiclass: 0.5255 - val_iou_multiclass: 0.3586 - val_loss: 1.3442 - learning_rate: 1.0000e-04
# Epoch 22/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.7797 - dice_coef_multiclass: 0.5145 - iou_multiclass: 0.3484 - loss: 1.4143
# Epoch 22: val_loss improved from 1.31326 to 1.24822, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 152ms/step - accuracy: 0.7799 - dice_coef_multiclass: 0.5146 - iou_multiclass: 0.3485 - loss: 1.4136 - val_accuracy: 0.8261 - val_dice_coef_multiclass: 0.5385 - val_iou_multiclass: 0.3701 - val_loss: 1.2482 - learning_rate: 1.0000e-04
# Epoch 23/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.7532 - dice_coef_multiclass: 0.5179 - iou_multiclass: 0.3518 - loss: 1.4138
# Epoch 23: val_loss did not improve from 1.24822
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 149ms/step - accuracy: 0.7535 - dice_coef_multiclass: 0.5180 - iou_multiclass: 0.3519 - loss: 1.4133 - val_accuracy: 0.8061 - val_dice_coef_multiclass: 0.5372 - val_iou_multiclass: 0.3689 - val_loss: 1.2730 - learning_rate: 1.0000e-04
# Epoch 24/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8038 - dice_coef_multiclass: 0.5290 - iou_multiclass: 0.3619 - loss: 1.3383
# Epoch 24: val_loss improved from 1.24822 to 1.21564, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 152ms/step - accuracy: 0.8039 - dice_coef_multiclass: 0.5291 - iou_multiclass: 0.3620 - loss: 1.3378 - val_accuracy: 0.8194 - val_dice_coef_multiclass: 0.5495 - val_iou_multiclass: 0.3807 - val_loss: 1.2156 - learning_rate: 1.0000e-04
# Epoch 25/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.7841 - dice_coef_multiclass: 0.5316 - iou_multiclass: 0.3641 - loss: 1.3403
# Epoch 25: val_loss did not improve from 1.21564
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.7844 - dice_coef_multiclass: 0.5317 - iou_multiclass: 0.3642 - loss: 1.3396 - val_accuracy: 0.8077 - val_dice_coef_multiclass: 0.5502 - val_iou_multiclass: 0.3817 - val_loss: 1.2265 - learning_rate: 1.0000e-04
# Epoch 26/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.7952 - dice_coef_multiclass: 0.5390 - iou_multiclass: 0.3714 - loss: 1.3100
# Epoch 26: val_loss improved from 1.21564 to 1.21172, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.7952 - dice_coef_multiclass: 0.5390 - iou_multiclass: 0.3714 - loss: 1.3097 - val_accuracy: 0.8113 - val_dice_coef_multiclass: 0.5523 - val_iou_multiclass: 0.3835 - val_loss: 1.2117 - learning_rate: 1.0000e-04
# Epoch 27/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.7993 - dice_coef_multiclass: 0.5440 - iou_multiclass: 0.3758 - loss: 1.3005
# Epoch 27: val_loss improved from 1.21172 to 1.18828, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 154ms/step - accuracy: 0.7994 - dice_coef_multiclass: 0.5441 - iou_multiclass: 0.3759 - loss: 1.2999 - val_accuracy: 0.8161 - val_dice_coef_multiclass: 0.5610 - val_iou_multiclass: 0.3923 - val_loss: 1.1883 - learning_rate: 1.0000e-04
# Epoch 28/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.7792 - dice_coef_multiclass: 0.5469 - iou_multiclass: 0.3790 - loss: 1.3106
# Epoch 28: val_loss improved from 1.18828 to 1.17955, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 149ms/step - accuracy: 0.7796 - dice_coef_multiclass: 0.5470 - iou_multiclass: 0.3791 - loss: 1.3097 - val_accuracy: 0.8214 - val_dice_coef_multiclass: 0.5626 - val_iou_multiclass: 0.3938 - val_loss: 1.1795 - learning_rate: 1.0000e-04
# Epoch 29/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8070 - dice_coef_multiclass: 0.5581 - iou_multiclass: 0.3895 - loss: 1.2367
# Epoch 29: val_loss improved from 1.17955 to 1.13071, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 155ms/step - accuracy: 0.8070 - dice_coef_multiclass: 0.5581 - iou_multiclass: 0.3895 - loss: 1.2365 - val_accuracy: 0.8220 - val_dice_coef_multiclass: 0.5765 - val_iou_multiclass: 0.4073 - val_loss: 1.1307 - learning_rate: 1.0000e-04
# Epoch 30/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.8218 - dice_coef_multiclass: 0.5648 - iou_multiclass: 0.3957 - loss: 1.2110
# Epoch 30: val_loss did not improve from 1.13071
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 9s 145ms/step - accuracy: 0.8217 - dice_coef_multiclass: 0.5648 - iou_multiclass: 0.3957 - loss: 1.2107 - val_accuracy: 0.8190 - val_dice_coef_multiclass: 0.5752 - val_iou_multiclass: 0.4063 - val_loss: 1.1357 - learning_rate: 1.0000e-04
# Epoch 31/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8001 - dice_coef_multiclass: 0.5657 - iou_multiclass: 0.3972 - loss: 1.2327
# Epoch 31: val_loss did not improve from 1.13071
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.8004 - dice_coef_multiclass: 0.5658 - iou_multiclass: 0.3972 - loss: 1.2319 - val_accuracy: 0.8008 - val_dice_coef_multiclass: 0.5720 - val_iou_multiclass: 0.4032 - val_loss: 1.1646 - learning_rate: 1.0000e-04
# Epoch 32/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.8147 - dice_coef_multiclass: 0.5676 - iou_multiclass: 0.3995 - loss: 1.2277
# Epoch 32: val_loss improved from 1.13071 to 1.06536, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 153ms/step - accuracy: 0.8146 - dice_coef_multiclass: 0.5677 - iou_multiclass: 0.3996 - loss: 1.2272 - val_accuracy: 0.8347 - val_dice_coef_multiclass: 0.6002 - val_iou_multiclass: 0.4319 - val_loss: 1.0654 - learning_rate: 1.0000e-04
# Epoch 33/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.8310 - dice_coef_multiclass: 0.5796 - iou_multiclass: 0.4107 - loss: 1.1561
# Epoch 33: val_loss did not improve from 1.06536
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 146ms/step - accuracy: 0.8309 - dice_coef_multiclass: 0.5796 - iou_multiclass: 0.4107 - loss: 1.1560 - val_accuracy: 0.8270 - val_dice_coef_multiclass: 0.5997 - val_iou_multiclass: 0.4321 - val_loss: 1.0952 - learning_rate: 1.0000e-04
# Epoch 34/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.8291 - dice_coef_multiclass: 0.5840 - iou_multiclass: 0.4151 - loss: 1.1518
# Epoch 34: val_loss did not improve from 1.06536
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 146ms/step - accuracy: 0.8291 - dice_coef_multiclass: 0.5841 - iou_multiclass: 0.4151 - loss: 1.1514 - val_accuracy: 0.8212 - val_dice_coef_multiclass: 0.6025 - val_iou_multiclass: 0.4347 - val_loss: 1.0822 - learning_rate: 1.0000e-04
# Epoch 35/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.7966 - dice_coef_multiclass: 0.5848 - iou_multiclass: 0.4162 - loss: 1.1801
# Epoch 35: val_loss improved from 1.06536 to 1.05290, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 155ms/step - accuracy: 0.7970 - dice_coef_multiclass: 0.5849 - iou_multiclass: 0.4163 - loss: 1.1793 - val_accuracy: 0.8296 - val_dice_coef_multiclass: 0.6106 - val_iou_multiclass: 0.4433 - val_loss: 1.0529 - learning_rate: 1.0000e-04
# Epoch 36/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.8190 - dice_coef_multiclass: 0.5932 - iou_multiclass: 0.4245 - loss: 1.1328
# Epoch 36: val_loss improved from 1.05290 to 1.03832, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.8192 - dice_coef_multiclass: 0.5933 - iou_multiclass: 0.4246 - loss: 1.1321 - val_accuracy: 0.8388 - val_dice_coef_multiclass: 0.6097 - val_iou_multiclass: 0.4416 - val_loss: 1.0383 - learning_rate: 1.0000e-04
# Epoch 37/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8297 - dice_coef_multiclass: 0.5996 - iou_multiclass: 0.4313 - loss: 1.1103
# Epoch 37: val_loss did not improve from 1.03832
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.8299 - dice_coef_multiclass: 0.5997 - iou_multiclass: 0.4313 - loss: 1.1098 - val_accuracy: 0.8251 - val_dice_coef_multiclass: 0.6177 - val_iou_multiclass: 0.4517 - val_loss: 1.0617 - learning_rate: 1.0000e-04
# Epoch 38/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.8154 - dice_coef_multiclass: 0.5999 - iou_multiclass: 0.4317 - loss: 1.1451
# Epoch 38: val_loss improved from 1.03832 to 1.00953, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 149ms/step - accuracy: 0.8156 - dice_coef_multiclass: 0.5999 - iou_multiclass: 0.4318 - loss: 1.1444 - val_accuracy: 0.8322 - val_dice_coef_multiclass: 0.6239 - val_iou_multiclass: 0.4574 - val_loss: 1.0095 - learning_rate: 1.0000e-04
# Epoch 39/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.7961 - dice_coef_multiclass: 0.5988 - iou_multiclass: 0.4313 - loss: 1.1646
# Epoch 39: val_loss did not improve from 1.00953
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.7965 - dice_coef_multiclass: 0.5989 - iou_multiclass: 0.4315 - loss: 1.1636 - val_accuracy: 0.7991 - val_dice_coef_multiclass: 0.6153 - val_iou_multiclass: 0.4498 - val_loss: 1.1155 - learning_rate: 1.0000e-04
# Epoch 40/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.7842 - dice_coef_multiclass: 0.5983 - iou_multiclass: 0.4313 - loss: 1.1876
# Epoch 40: val_loss did not improve from 1.00953
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.7845 - dice_coef_multiclass: 0.5984 - iou_multiclass: 0.4315 - loss: 1.1865 - val_accuracy: 0.8219 - val_dice_coef_multiclass: 0.6387 - val_iou_multiclass: 0.4752 - val_loss: 1.0304 - learning_rate: 1.0000e-04
# Epoch 41/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.7736 - dice_coef_multiclass: 0.6038 - iou_multiclass: 0.4367 - loss: 1.1843
# Epoch 41: val_loss did not improve from 1.00953
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.7741 - dice_coef_multiclass: 0.6039 - iou_multiclass: 0.4369 - loss: 1.1830 - val_accuracy: 0.8263 - val_dice_coef_multiclass: 0.6246 - val_iou_multiclass: 0.4582 - val_loss: 1.0311 - learning_rate: 1.0000e-04
# Epoch 42/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.8074 - dice_coef_multiclass: 0.6113 - iou_multiclass: 0.4444 - loss: 1.1353
# Epoch 42: val_loss did not improve from 1.00953
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 150ms/step - accuracy: 0.8076 - dice_coef_multiclass: 0.6114 - iou_multiclass: 0.4445 - loss: 1.1346 - val_accuracy: 0.8075 - val_dice_coef_multiclass: 0.6308 - val_iou_multiclass: 0.4660 - val_loss: 1.0510 - learning_rate: 1.0000e-04
# Epoch 43/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8263 - dice_coef_multiclass: 0.6192 - iou_multiclass: 0.4520 - loss: 1.0907
# Epoch 43: val_loss did not improve from 1.00953
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.8264 - dice_coef_multiclass: 0.6193 - iou_multiclass: 0.4521 - loss: 1.0900 - val_accuracy: 0.8182 - val_dice_coef_multiclass: 0.6316 - val_iou_multiclass: 0.4657 - val_loss: 1.0138 - learning_rate: 1.0000e-04
# Epoch 44/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.8139 - dice_coef_multiclass: 0.6228 - iou_multiclass: 0.4561 - loss: 1.0993
# Epoch 44: val_loss improved from 1.00953 to 0.97947, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.8141 - dice_coef_multiclass: 0.6229 - iou_multiclass: 0.4562 - loss: 1.0986 - val_accuracy: 0.8312 - val_dice_coef_multiclass: 0.6365 - val_iou_multiclass: 0.4702 - val_loss: 0.9795 - learning_rate: 1.0000e-04
# Epoch 45/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.8279 - dice_coef_multiclass: 0.6317 - iou_multiclass: 0.4650 - loss: 1.0394
# Epoch 45: val_loss did not improve from 0.97947
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 149ms/step - accuracy: 0.8279 - dice_coef_multiclass: 0.6317 - iou_multiclass: 0.4651 - loss: 1.0393 - val_accuracy: 0.8028 - val_dice_coef_multiclass: 0.6430 - val_iou_multiclass: 0.4780 - val_loss: 0.9971 - learning_rate: 1.0000e-04
# Epoch 46/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8291 - dice_coef_multiclass: 0.6348 - iou_multiclass: 0.4685 - loss: 1.0443
# Epoch 46: val_loss improved from 0.97947 to 0.94902, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 152ms/step - accuracy: 0.8292 - dice_coef_multiclass: 0.6348 - iou_multiclass: 0.4686 - loss: 1.0440 - val_accuracy: 0.8334 - val_dice_coef_multiclass: 0.6492 - val_iou_multiclass: 0.4847 - val_loss: 0.9490 - learning_rate: 1.0000e-04
# Epoch 47/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.8052 - dice_coef_multiclass: 0.6312 - iou_multiclass: 0.4659 - loss: 1.0897
# Epoch 47: val_loss improved from 0.94902 to 0.93307, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8054 - dice_coef_multiclass: 0.6314 - iou_multiclass: 0.4661 - loss: 1.0886 - val_accuracy: 0.8431 - val_dice_coef_multiclass: 0.6601 - val_iou_multiclass: 0.4978 - val_loss: 0.9331 - learning_rate: 1.0000e-04
# Epoch 48/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8185 - dice_coef_multiclass: 0.6424 - iou_multiclass: 0.4775 - loss: 1.0324
# Epoch 48: val_loss did not improve from 0.93307
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8188 - dice_coef_multiclass: 0.6425 - iou_multiclass: 0.4776 - loss: 1.0318 - val_accuracy: 0.8231 - val_dice_coef_multiclass: 0.6574 - val_iou_multiclass: 0.4946 - val_loss: 0.9666 - learning_rate: 1.0000e-04
# Epoch 49/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8365 - dice_coef_multiclass: 0.6438 - iou_multiclass: 0.4799 - loss: 1.0341
# Epoch 49: val_loss did not improve from 0.93307
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 153ms/step - accuracy: 0.8365 - dice_coef_multiclass: 0.6439 - iou_multiclass: 0.4800 - loss: 1.0335 - val_accuracy: 0.8009 - val_dice_coef_multiclass: 0.6638 - val_iou_multiclass: 0.5029 - val_loss: 0.9889 - learning_rate: 1.0000e-04
# Epoch 50/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8166 - dice_coef_multiclass: 0.6394 - iou_multiclass: 0.4749 - loss: 1.0785
# Epoch 50: val_loss did not improve from 0.93307
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8169 - dice_coef_multiclass: 0.6396 - iou_multiclass: 0.4751 - loss: 1.0772 - val_accuracy: 0.8215 - val_dice_coef_multiclass: 0.6665 - val_iou_multiclass: 0.5062 - val_loss: 0.9789 - learning_rate: 1.0000e-04
# Epoch 51/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8109 - dice_coef_multiclass: 0.6453 - iou_multiclass: 0.4822 - loss: 1.0803
# Epoch 51: val_loss did not improve from 0.93307
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.8113 - dice_coef_multiclass: 0.6455 - iou_multiclass: 0.4824 - loss: 1.0787 - val_accuracy: 0.8217 - val_dice_coef_multiclass: 0.6624 - val_iou_multiclass: 0.5005 - val_loss: 0.9593 - learning_rate: 1.0000e-04
# Epoch 52/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.8328 - dice_coef_multiclass: 0.6517 - iou_multiclass: 0.4890 - loss: 1.0348
# Epoch 52: val_loss did not improve from 0.93307
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 152ms/step - accuracy: 0.8329 - dice_coef_multiclass: 0.6518 - iou_multiclass: 0.4891 - loss: 1.0339 - val_accuracy: 0.8014 - val_dice_coef_multiclass: 0.6750 - val_iou_multiclass: 0.5171 - val_loss: 0.9779 - learning_rate: 1.0000e-04
# Epoch 53/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.8269 - dice_coef_multiclass: 0.6596 - iou_multiclass: 0.4977 - loss: 1.0148
# Epoch 53: val_loss improved from 0.93307 to 0.93021, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.8270 - dice_coef_multiclass: 0.6597 - iou_multiclass: 0.4978 - loss: 1.0139 - val_accuracy: 0.8165 - val_dice_coef_multiclass: 0.6695 - val_iou_multiclass: 0.5081 - val_loss: 0.9302 - learning_rate: 1.0000e-04
# Epoch 54/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8290 - dice_coef_multiclass: 0.6610 - iou_multiclass: 0.4996 - loss: 1.0200
# Epoch 54: val_loss did not improve from 0.93021
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8293 - dice_coef_multiclass: 0.6612 - iou_multiclass: 0.4998 - loss: 1.0188 - val_accuracy: 0.7837 - val_dice_coef_multiclass: 0.6664 - val_iou_multiclass: 0.5086 - val_loss: 1.0383 - learning_rate: 1.0000e-04
# Epoch 55/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.7927 - dice_coef_multiclass: 0.6570 - iou_multiclass: 0.4961 - loss: 1.0806
# Epoch 55: val_loss did not improve from 0.93021
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.7932 - dice_coef_multiclass: 0.6571 - iou_multiclass: 0.4963 - loss: 1.0792 - val_accuracy: 0.7838 - val_dice_coef_multiclass: 0.6608 - val_iou_multiclass: 0.5009 - val_loss: 1.0484 - learning_rate: 1.0000e-04
# Epoch 56/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8413 - dice_coef_multiclass: 0.6704 - iou_multiclass: 0.5093 - loss: 0.9882
# Epoch 56: val_loss did not improve from 0.93021
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.8416 - dice_coef_multiclass: 0.6705 - iou_multiclass: 0.5095 - loss: 0.9870 - val_accuracy: 0.7899 - val_dice_coef_multiclass: 0.6731 - val_iou_multiclass: 0.5151 - val_loss: 1.0176 - learning_rate: 1.0000e-04
# Epoch 57/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8336 - dice_coef_multiclass: 0.6684 - iou_multiclass: 0.5082 - loss: 1.0208
# Epoch 57: val_loss did not improve from 0.93021
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8338 - dice_coef_multiclass: 0.6685 - iou_multiclass: 0.5083 - loss: 1.0198 - val_accuracy: 0.7879 - val_dice_coef_multiclass: 0.6929 - val_iou_multiclass: 0.5407 - val_loss: 1.0083 - learning_rate: 1.0000e-04
# Epoch 58/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.8362 - dice_coef_multiclass: 0.6794 - iou_multiclass: 0.5208 - loss: 0.9572
# Epoch 58: val_loss did not improve from 0.93021
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 151ms/step - accuracy: 0.8362 - dice_coef_multiclass: 0.6794 - iou_multiclass: 0.5209 - loss: 0.9568 - val_accuracy: 0.7701 - val_dice_coef_multiclass: 0.6796 - val_iou_multiclass: 0.5227 - val_loss: 1.0091 - learning_rate: 1.0000e-04
# Epoch 59/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.8016 - dice_coef_multiclass: 0.6758 - iou_multiclass: 0.5176 - loss: 0.9981
# Epoch 59: val_loss did not improve from 0.93021
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8019 - dice_coef_multiclass: 0.6759 - iou_multiclass: 0.5177 - loss: 0.9973 - val_accuracy: 0.7919 - val_dice_coef_multiclass: 0.6894 - val_iou_multiclass: 0.5347 - val_loss: 0.9663 - learning_rate: 1.0000e-04
# Epoch 60/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8082 - dice_coef_multiclass: 0.6706 - iou_multiclass: 0.5117 - loss: 1.0647
# Epoch 60: val_loss did not improve from 0.93021
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8087 - dice_coef_multiclass: 0.6708 - iou_multiclass: 0.5119 - loss: 1.0628 - val_accuracy: 0.7817 - val_dice_coef_multiclass: 0.6885 - val_iou_multiclass: 0.5396 - val_loss: 1.0923 - learning_rate: 1.0000e-04
# Epoch 61/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8204 - dice_coef_multiclass: 0.6759 - iou_multiclass: 0.5175 - loss: 1.0328
# Epoch 61: val_loss did not improve from 0.93021
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.8206 - dice_coef_multiclass: 0.6760 - iou_multiclass: 0.5176 - loss: 1.0314 - val_accuracy: 0.7987 - val_dice_coef_multiclass: 0.6928 - val_iou_multiclass: 0.5391 - val_loss: 0.9587 - learning_rate: 1.0000e-04
# Epoch 62/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.8367 - dice_coef_multiclass: 0.6892 - iou_multiclass: 0.5325 - loss: 0.9420
# Epoch 62: val_loss did not improve from 0.93021
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 150ms/step - accuracy: 0.8368 - dice_coef_multiclass: 0.6893 - iou_multiclass: 0.5326 - loss: 0.9412 - val_accuracy: 0.7885 - val_dice_coef_multiclass: 0.6940 - val_iou_multiclass: 0.5420 - val_loss: 0.9926 - learning_rate: 1.0000e-04
# Epoch 63/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8475 - dice_coef_multiclass: 0.6877 - iou_multiclass: 0.5305 - loss: 0.9638
# Epoch 63: val_loss did not improve from 0.93021
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8475 - dice_coef_multiclass: 0.6877 - iou_multiclass: 0.5305 - loss: 0.9635 - val_accuracy: 0.7634 - val_dice_coef_multiclass: 0.6799 - val_iou_multiclass: 0.5260 - val_loss: 1.0533 - learning_rate: 1.0000e-04
# Epoch 64/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8250 - dice_coef_multiclass: 0.6866 - iou_multiclass: 0.5303 - loss: 0.9880
# Epoch 64: val_loss did not improve from 0.93021
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8251 - dice_coef_multiclass: 0.6867 - iou_multiclass: 0.5305 - loss: 0.9869 - val_accuracy: 0.7827 - val_dice_coef_multiclass: 0.6867 - val_iou_multiclass: 0.5305 - val_loss: 0.9844 - learning_rate: 1.0000e-04
# Epoch 65/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8436 - dice_coef_multiclass: 0.6916 - iou_multiclass: 0.5360 - loss: 0.9564
# Epoch 65: val_loss improved from 0.93021 to 0.91424, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 151ms/step - accuracy: 0.8436 - dice_coef_multiclass: 0.6917 - iou_multiclass: 0.5361 - loss: 0.9556 - val_accuracy: 0.7944 - val_dice_coef_multiclass: 0.6996 - val_iou_multiclass: 0.5453 - val_loss: 0.9142 - learning_rate: 1.0000e-04
# Epoch 66/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.8545 - dice_coef_multiclass: 0.7007 - iou_multiclass: 0.5465 - loss: 0.9191
# Epoch 66: val_loss did not improve from 0.91424
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 9s 144ms/step - accuracy: 0.8545 - dice_coef_multiclass: 0.7007 - iou_multiclass: 0.5466 - loss: 0.9184 - val_accuracy: 0.7677 - val_dice_coef_multiclass: 0.6949 - val_iou_multiclass: 0.5402 - val_loss: 0.9731 - learning_rate: 1.0000e-04
# Epoch 67/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8393 - dice_coef_multiclass: 0.6948 - iou_multiclass: 0.5400 - loss: 0.9837
# Epoch 67: val_loss improved from 0.91424 to 0.87748, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 152ms/step - accuracy: 0.8394 - dice_coef_multiclass: 0.6950 - iou_multiclass: 0.5402 - loss: 0.9829 - val_accuracy: 0.8030 - val_dice_coef_multiclass: 0.7149 - val_iou_multiclass: 0.5637 - val_loss: 0.8775 - learning_rate: 1.0000e-04
# Epoch 68/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8163 - dice_coef_multiclass: 0.6965 - iou_multiclass: 0.5425 - loss: 0.9821
# Epoch 68: val_loss did not improve from 0.87748
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8165 - dice_coef_multiclass: 0.6967 - iou_multiclass: 0.5427 - loss: 0.9810 - val_accuracy: 0.7554 - val_dice_coef_multiclass: 0.6999 - val_iou_multiclass: 0.5498 - val_loss: 1.0215 - learning_rate: 1.0000e-04
# Epoch 69/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.8150 - dice_coef_multiclass: 0.6921 - iou_multiclass: 0.5370 - loss: 1.0308
# Epoch 69: val_loss did not improve from 0.87748
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 146ms/step - accuracy: 0.8154 - dice_coef_multiclass: 0.6923 - iou_multiclass: 0.5373 - loss: 1.0290 - val_accuracy: 0.7706 - val_dice_coef_multiclass: 0.6994 - val_iou_multiclass: 0.5475 - val_loss: 0.9758 - learning_rate: 1.0000e-04
# Epoch 70/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.8241 - dice_coef_multiclass: 0.6938 - iou_multiclass: 0.5402 - loss: 1.0188
# Epoch 70: val_loss improved from 0.87748 to 0.86462, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.8245 - dice_coef_multiclass: 0.6940 - iou_multiclass: 0.5404 - loss: 1.0169 - val_accuracy: 0.8096 - val_dice_coef_multiclass: 0.7161 - val_iou_multiclass: 0.5649 - val_loss: 0.8646 - learning_rate: 1.0000e-04
# Epoch 71/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8336 - dice_coef_multiclass: 0.6945 - iou_multiclass: 0.5396 - loss: 1.0037
# Epoch 71: val_loss did not improve from 0.86462
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.8339 - dice_coef_multiclass: 0.6947 - iou_multiclass: 0.5399 - loss: 1.0019 - val_accuracy: 0.7966 - val_dice_coef_multiclass: 0.7062 - val_iou_multiclass: 0.5533 - val_loss: 0.9145 - learning_rate: 1.0000e-04
# Epoch 72/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8411 - dice_coef_multiclass: 0.7034 - iou_multiclass: 0.5505 - loss: 0.9534
# Epoch 72: val_loss did not improve from 0.86462
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8412 - dice_coef_multiclass: 0.7035 - iou_multiclass: 0.5507 - loss: 0.9525 - val_accuracy: 0.7602 - val_dice_coef_multiclass: 0.7064 - val_iou_multiclass: 0.5584 - val_loss: 0.9854 - learning_rate: 1.0000e-04
# Epoch 73/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8499 - dice_coef_multiclass: 0.7086 - iou_multiclass: 0.5561 - loss: 0.9199
# Epoch 73: val_loss did not improve from 0.86462
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 146ms/step - accuracy: 0.8499 - dice_coef_multiclass: 0.7088 - iou_multiclass: 0.5562 - loss: 0.9189 - val_accuracy: 0.7804 - val_dice_coef_multiclass: 0.7230 - val_iou_multiclass: 0.5824 - val_loss: 1.0108 - learning_rate: 1.0000e-04
# Epoch 74/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.5961 - dice_coef_multiclass: 0.6026 - iou_multiclass: 0.4436 - loss: 1.8449
# Epoch 74: val_loss did not improve from 0.86462
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 9s 145ms/step - accuracy: 0.5962 - dice_coef_multiclass: 0.6026 - iou_multiclass: 0.4436 - loss: 1.8434 - val_accuracy: 0.5848 - val_dice_coef_multiclass: 0.6380 - val_iou_multiclass: 0.4705 - val_loss: 1.2338 - learning_rate: 1.0000e-04
# Epoch 75/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.7097 - dice_coef_multiclass: 0.6370 - iou_multiclass: 0.4723 - loss: 1.2281
# Epoch 75: val_loss improved from 0.86462 to 0.82585, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 153ms/step - accuracy: 0.7106 - dice_coef_multiclass: 0.6374 - iou_multiclass: 0.4727 - loss: 1.2257 - val_accuracy: 0.8619 - val_dice_coef_multiclass: 0.7178 - val_iou_multiclass: 0.5659 - val_loss: 0.8259 - learning_rate: 1.0000e-04
# Epoch 76/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.8206 - dice_coef_multiclass: 0.6824 - iou_multiclass: 0.5230 - loss: 0.9829
# Epoch 76: val_loss improved from 0.82585 to 0.80278, saving model to /kaggle/working//unet_original.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 146ms/step - accuracy: 0.8209 - dice_coef_multiclass: 0.6826 - iou_multiclass: 0.5233 - loss: 0.9816 - val_accuracy: 0.8780 - val_dice_coef_multiclass: 0.7157 - val_iou_multiclass: 0.5627 - val_loss: 0.8028 - learning_rate: 1.0000e-04
# Epoch 77/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.8504 - dice_coef_multiclass: 0.7038 - iou_multiclass: 0.5476 - loss: 0.8951
# Epoch 77: val_loss did not improve from 0.80278
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 9s 144ms/step - accuracy: 0.8504 - dice_coef_multiclass: 0.7039 - iou_multiclass: 0.5477 - loss: 0.8946 - val_accuracy: 0.8465 - val_dice_coef_multiclass: 0.7112 - val_iou_multiclass: 0.5570 - val_loss: 0.8209 - learning_rate: 1.0000e-04
# Epoch 78/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8222 - dice_coef_multiclass: 0.6991 - iou_multiclass: 0.5451 - loss: 0.9647
# Epoch 78: val_loss did not improve from 0.80278
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8226 - dice_coef_multiclass: 0.6993 - iou_multiclass: 0.5453 - loss: 0.9633 - val_accuracy: 0.8264 - val_dice_coef_multiclass: 0.7090 - val_iou_multiclass: 0.5549 - val_loss: 0.8514 - learning_rate: 1.0000e-04
# Epoch 79/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8125 - dice_coef_multiclass: 0.7047 - iou_multiclass: 0.5529 - loss: 0.9620
# Epoch 79: val_loss did not improve from 0.80278
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.8129 - dice_coef_multiclass: 0.7048 - iou_multiclass: 0.5530 - loss: 0.9608 - val_accuracy: 0.8071 - val_dice_coef_multiclass: 0.7265 - val_iou_multiclass: 0.5790 - val_loss: 0.8514 - learning_rate: 1.0000e-04
# Epoch 80/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.8419 - dice_coef_multiclass: 0.7069 - iou_multiclass: 0.5539 - loss: 0.9206
# Epoch 80: val_loss did not improve from 0.80278
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 9s 145ms/step - accuracy: 0.8421 - dice_coef_multiclass: 0.7070 - iou_multiclass: 0.5541 - loss: 0.9196 - val_accuracy: 0.7848 - val_dice_coef_multiclass: 0.7150 - val_iou_multiclass: 0.5656 - val_loss: 0.9023 - learning_rate: 1.0000e-04
# Epoch 81/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8389 - dice_coef_multiclass: 0.7132 - iou_multiclass: 0.5617 - loss: 0.9168
# Epoch 81: val_loss did not improve from 0.80278
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 152ms/step - accuracy: 0.8391 - dice_coef_multiclass: 0.7133 - iou_multiclass: 0.5618 - loss: 0.9158 - val_accuracy: 0.7921 - val_dice_coef_multiclass: 0.7350 - val_iou_multiclass: 0.5952 - val_loss: 0.9450 - learning_rate: 1.0000e-04
# Epoch 82/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8247 - dice_coef_multiclass: 0.7126 - iou_multiclass: 0.5621 - loss: 0.9463
# Epoch 82: val_loss did not improve from 0.80278
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8253 - dice_coef_multiclass: 0.7127 - iou_multiclass: 0.5623 - loss: 0.9447 - val_accuracy: 0.8112 - val_dice_coef_multiclass: 0.7383 - val_iou_multiclass: 0.5953 - val_loss: 0.8525 - learning_rate: 1.0000e-04
# Epoch 83/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8351 - dice_coef_multiclass: 0.7149 - iou_multiclass: 0.5651 - loss: 0.9206
# Epoch 83: val_loss did not improve from 0.80278
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8352 - dice_coef_multiclass: 0.7151 - iou_multiclass: 0.5652 - loss: 0.9196 - val_accuracy: 0.7768 - val_dice_coef_multiclass: 0.7385 - val_iou_multiclass: 0.6006 - val_loss: 0.9536 - learning_rate: 1.0000e-04
# Epoch 84/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.8354 - dice_coef_multiclass: 0.7140 - iou_multiclass: 0.5643 - loss: 0.9206
# Epoch 84: val_loss did not improve from 0.80278
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8356 - dice_coef_multiclass: 0.7141 - iou_multiclass: 0.5645 - loss: 0.9197 - val_accuracy: 0.8032 - val_dice_coef_multiclass: 0.7476 - val_iou_multiclass: 0.6096 - val_loss: 0.8718 - learning_rate: 1.0000e-04
# Epoch 85/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8191 - dice_coef_multiclass: 0.7153 - iou_multiclass: 0.5658 - loss: 0.9421
# Epoch 85: val_loss did not improve from 0.80278
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8195 - dice_coef_multiclass: 0.7155 - iou_multiclass: 0.5660 - loss: 0.9407 - val_accuracy: 0.8072 - val_dice_coef_multiclass: 0.7383 - val_iou_multiclass: 0.5947 - val_loss: 0.8412 - learning_rate: 1.0000e-04
# Epoch 86/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.8567 - dice_coef_multiclass: 0.7260 - iou_multiclass: 0.5778 - loss: 0.8705
# Epoch 86: val_loss did not improve from 0.80278
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 9s 144ms/step - accuracy: 0.8567 - dice_coef_multiclass: 0.7262 - iou_multiclass: 0.5779 - loss: 0.8695 - val_accuracy: 0.7949 - val_dice_coef_multiclass: 0.7386 - val_iou_multiclass: 0.5984 - val_loss: 0.9029 - learning_rate: 1.0000e-04
# Epoch 87/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.8430 - dice_coef_multiclass: 0.7235 - iou_multiclass: 0.5766 - loss: 0.9105
# Epoch 87: val_loss did not improve from 0.80278
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 146ms/step - accuracy: 0.8432 - dice_coef_multiclass: 0.7236 - iou_multiclass: 0.5767 - loss: 0.9096 - val_accuracy: 0.7767 - val_dice_coef_multiclass: 0.7400 - val_iou_multiclass: 0.6016 - val_loss: 0.9124 - learning_rate: 1.0000e-04
# Epoch 88/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8597 - dice_coef_multiclass: 0.7309 - iou_multiclass: 0.5851 - loss: 0.8725
# Epoch 88: val_loss did not improve from 0.80278
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.8597 - dice_coef_multiclass: 0.7310 - iou_multiclass: 0.5852 - loss: 0.8715 - val_accuracy: 0.7580 - val_dice_coef_multiclass: 0.7211 - val_iou_multiclass: 0.5753 - val_loss: 0.9840 - learning_rate: 1.0000e-04
# Epoch 89/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8469 - dice_coef_multiclass: 0.7337 - iou_multiclass: 0.5889 - loss: 0.8520
# Epoch 89: val_loss did not improve from 0.80278
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8471 - dice_coef_multiclass: 0.7338 - iou_multiclass: 0.5890 - loss: 0.8513 - val_accuracy: 0.7690 - val_dice_coef_multiclass: 0.7345 - val_iou_multiclass: 0.5921 - val_loss: 0.9050 - learning_rate: 1.0000e-04
# Epoch 90/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.8160 - dice_coef_multiclass: 0.7203 - iou_multiclass: 0.5729 - loss: 0.9351
# Epoch 90: val_loss did not improve from 0.80278
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 146ms/step - accuracy: 0.8163 - dice_coef_multiclass: 0.7204 - iou_multiclass: 0.5731 - loss: 0.9339 - val_accuracy: 0.7916 - val_dice_coef_multiclass: 0.7416 - val_iou_multiclass: 0.6021 - val_loss: 0.8869 - learning_rate: 1.0000e-04
# Epoch 91/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8121 - dice_coef_multiclass: 0.7268 - iou_multiclass: 0.5801 - loss: 0.9290
# Epoch 91: val_loss did not improve from 0.80278
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.8127 - dice_coef_multiclass: 0.7270 - iou_multiclass: 0.5803 - loss: 0.9271 - val_accuracy: 0.7545 - val_dice_coef_multiclass: 0.7244 - val_iou_multiclass: 0.5854 - val_loss: 1.0529 - learning_rate: 1.0000e-04

# %%
# Print the final training/validation loss and accuracy values
print("Final Training Loss: ", history.history['loss'][-1])
print("Final Validation Loss: ", history.history['val_loss'][-1])
print("Final Training Accuracy: ", history.history['accuracy'][-1])
print("Final Validation Accuracy: ", history.history['val_accuracy'][-1])
print("Final Training Dice Coefficient: ", history.history['dice_coef_multiclass'][-1])
print("Final Validation Dice Coefficient: ", history.history['val_dice_coef_multiclass'][-1])
print("Final Training IoU: ", history.history['iou_multiclass'][-1])
print("Final Validation IoU: ", history.history['val_iou_multiclass'][-1])
# Out:
# Final Training Loss:  0.802761435508728
# Final Validation Loss:  1.0528819561004639
# Final Training Accuracy:  0.8565564751625061
# Final Validation Accuracy:  0.7544596791267395
# Final Training Dice Coefficient:  0.7409182786941528
# Final Validation Dice Coefficient:  0.7244449257850647
# Final Training IoU:  0.5973950028419495
# Final Validation IoU:  0.5853686928749084

# %%
import matplotlib.pyplot as plt

# Plot training & validation loss, dice coefficient, and IoU over epochs
def plot_training_history(history):
    # Summarize history for loss, dice coefficient, and IoU
    plt.figure(figsize=(18, 6))  # Increase figure size for 3 plots

    # Plot loss
    plt.subplot(1, 3, 1)  # 1 row, 3 columns, first plot
    plt.plot(history.history['loss'], label='train_loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(loc='upper right')

    # Plot Dice Coefficient
    plt.subplot(1, 3, 2)  # 1 row, 3 columns, second plot
    plt.plot(history.history['dice_coef_multiclass'], label='train_dice_coef')
    plt.plot(history.history['val_dice_coef_multiclass'], label='val_dice_coef')
    plt.title('Model Dice Coefficient')
    plt.ylabel('Dice Coefficient')
    plt.xlabel('Epoch')
    plt.legend(loc='upper right')

    # Plot IoU
    plt.subplot(1, 3, 3)  # 1 row, 3 columns, third plot
    plt.plot(history.history['iou_multiclass'], label='train_iou_metric')
    plt.plot(history.history['val_iou_multiclass'], label='val_iou_metric')
    plt.title('Model IoU')
    plt.ylabel('IoU')
    plt.xlabel('Epoch')
    plt.legend(loc='upper right')

    plt.tight_layout()  # Adjust layout for better spacing
    plt.show()

# Call the function to plot
plot_training_history(history)
